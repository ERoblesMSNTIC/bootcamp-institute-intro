# %% [markdown]
# # Sesión 03: Exploración y Visualización de Datos de Producción Petrolera
# # Laboratorio Práctico
#
# Este notebook es parte del programa de Machine Learning Aplicado para la industria petrolera.
# En esta sesión aprenderemos a:
# 1. Realizar análisis exploratorio de datos (EDA) en datasets de producción petrolera
# 2. Aplicar técnicas estadísticas descriptivas para entender nuestros datos
# 3. Crear visualizaciones efectivas para comunicar patrones y tendencias
# 4. Identificar insights que pueden generar valor operativo

# %%
# Instalación de las librerías en caso de no tenerlas
#!pip install numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (2.2.4)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# Importamos las librerías necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Para visualizaciones interactivas
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Configuramos opciones de visualización
plt.style.use('seaborn-v0_8-whitegrid')  # Estilo visual limpio
sns.set_palette("deep")  # Paleta de colores contrastante
pd.set_option('display.max_columns', None)  # Mostrar todas las columnas

print("¡Entorno configurado correctamente!")
# Out:
# ¡Entorno configurado correctamente!

# %% [markdown]
# ## 1. Carga y Exploración Inicial de Datos
#
# Comenzaremos cargando un conjunto de datos de producción petrolera. Este
# dataset contiene información diaria sobre varios pozos, incluyendo:
# - Tasas de producción (petróleo, gas, agua)
# - Presiones (cabezal, línea)
# - Parámetros operativos (horas operativas, choke)
# - Información contextual (fecha, pozo, campo)

# %%
# Cargamos los datos
# En un entorno real, podríamos hacer:
# df = pd.read_csv("data/produccion_petrolera.csv")

# Para este ejercicio utilizaremos datos sintéticos
# que recrean patrones típicos de la industria

# Generamos datos sintéticos para el laboratorio
np.random.seed(42)  # Para reproducibilidad

# Período de tiempo: 365 días
fechas = pd.date_range(start='2022-01-01', periods=365, freq='D')

# Creamos 5 pozos con características diferentes
pozos = ['POZO-A', 'POZO-B', 'POZO-C', 'POZO-D', 'POZO-E']

# Lista para almacenar los datos
datos = []

# %%
# Función para crear un patrón de producción realista con tendencia de declinación
def generar_produccion(dias, tasa_inicial, declive_anual=0.2, ruido=0.1, intervencion=None):
    # Tendencia de declive exponencial (común en pozos petroleros)
    declive_diario = (1 - declive_anual) ** (1/365)
    tendencia = tasa_inicial * declive_diario ** np.arange(dias)
    
    # Agregamos ruido para simular variaciones naturales
    ruido = np.random.normal(0, ruido * tasa_inicial, dias)
    produccion = tendencia + ruido
    
    # Opcional: simulamos una intervención (workover) que mejora la producción
    if intervencion:
        dia_intervencion, mejora = intervencion
        if dia_intervencion < dias:
            produccion[dia_intervencion:] = produccion[dia_intervencion:] * mejora
    
    return np.maximum(0, produccion)  # No puede haber producción negativa

# %%
# Generamos datos para cada pozo
for pozo in pozos:
    # Cada pozo tiene características distintas
    if pozo == 'POZO-A':
        # Pozo con alta producción inicial y rápida declinación
        prod_petroleo = generar_produccion(365, 1200, declive_anual=0.4, intervencion=(180, 1.5))
        prod_gas = prod_petroleo * 1.2 + np.random.normal(0, 50, 365)
        prod_agua = generar_produccion(365, 200, declive_anual=-0.5)  # Incremento de agua
        
    elif pozo == 'POZO-B':
        # Pozo estable con baja declinación
        prod_petroleo = generar_produccion(365, 800, declive_anual=0.15)
        prod_gas = prod_petroleo * 0.8 + np.random.normal(0, 30, 365)
        prod_agua = generar_produccion(365, 300, declive_anual=0.1)
        
    elif pozo == 'POZO-C':
        # Pozo con problemas operativos (caídas súbitas)
        prod_petroleo = generar_produccion(365, 950, declive_anual=0.25)
        # Simulamos problemas en ciertos días
        for problema in [50, 120, 200, 280]:
            ventana = np.random.randint(3, 10)  # Duración del problema
            prod_petroleo[problema:problema+ventana] *= 0.3
        prod_gas = prod_petroleo * 1.5 + np.random.normal(0, 40, 365)
        prod_agua = generar_produccion(365, 250, declive_anual=0.05)
        
    elif pozo == 'POZO-D':
        # Pozo nuevo con alta producción
        prod_petroleo = generar_produccion(365, 1500, declive_anual=0.3)
        prod_gas = prod_petroleo * 1.1 + np.random.normal(0, 60, 365)
        prod_agua = generar_produccion(365, 100, declive_anual=-0.3)
        
    else:  # POZO-E
        # Pozo maduro con oscilaciones
        prod_petroleo = generar_produccion(365, 500, declive_anual=0.1, ruido=0.2)
        prod_gas = prod_petroleo * 0.7 + np.random.normal(0, 20, 365)
        prod_agua = generar_produccion(365, 700, declive_anual=-0.1)
    
    # Parámetros operativos
    presion_cabezal = np.random.normal(1800, 100, 365) - np.arange(365) * 0.2
    presion_linea = np.random.normal(800, 50, 365)
    temperatura = np.random.normal(80, 5, 365) + np.sin(np.arange(365) * 2 * np.pi / 365) * 3
    choke = 50 + np.random.normal(0, 5, 365)
    horas_operativas = np.random.normal(23, 1, 365)
    
    # Ajustamos valores a rangos realistas
    choke = np.clip(choke, 0, 100)
    horas_operativas = np.clip(horas_operativas, 0, 24)
    
    # Creamos registros diarios para este pozo
    for i, fecha in enumerate(fechas):
        registro = {
            'fecha': fecha,
            'pozo': pozo,
            'campo': 'CAMPO-' + pozo[-1],  # Agrupamos por el último carácter del nombre
            'petroleo_bbl': max(0, prod_petroleo[i]),
            'gas_mscf': max(0, prod_gas[i]),
            'agua_bbl': max(0, prod_agua[i]),
            'presion_cabezal_psi': max(0, presion_cabezal[i]),
            'presion_linea_psi': max(0, presion_linea[i]),
            'temperatura_c': temperatura[i],
            'choke_percent': choke[i],
            'horas_operativas': horas_operativas[i]
        }
        
        datos.append(registro)

# %%
datos
# Out:
# [{'fecha': Timestamp('2022-01-01 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1259.605698361348),
#   'gas_mscf': np.float64(1491.4658144393259),
#   'agua_bbl': np.float64(203.91690510195363),
#   'presion_cabezal_psi': np.float64(1791.9283419891417),
#   'presion_linea_psi': np.float64(793.0772008008113),
#   'temperatura_c': np.float64(82.20970324784705),
#   'choke_percent': np.float64(42.00937824058126),
#   'horas_operativas': np.float64(23.534629086122436)},
#  {'fecha': Timestamp('2022-01-02 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1181.7300318006683),
#   'gas_mscf': np.float64(1429.2806622513226),
#   'agua_bbl': np.float64(180.6548405571126),
#   'presion_cabezal_psi': np.float64(1807.663519031609),
#   'presion_linea_psi': np.float64(738.7850881855317),
#   'temperatura_c': np.float64(74.59964468125328),
#   'choke_percent': np.float64(52.31086333040972),
#   'horas_operativas': np.float64(20.364252260983122)},
#  {'fecha': Timestamp('2022-01-03 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1274.3684675628142),
#   'gas_mscf': np.float64(1529.8717811144668),
#   'agua_bbl': np.float64(208.6098944109172),
#   'presion_cabezal_psi': np.float64(1599.7799315467892),
#   'presion_linea_psi': np.float64(789.5488371356987),
#   'temperatura_c': np.float64(87.1579267335996),
#   'choke_percent': np.float64(60.12154811643426),
#   'horas_operativas': np.float64(23.003375506597163)},
#  {'fecha': Timestamp('2022-01-04 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1377.735864634993),
#   'gas_mscf': np.float64(1658.1668424894333),
#   'agua_bbl': np.float64(166.61595775150903),
#   'presion_cabezal_psi': np.float64(1891.0327674702482),
#   'presion_linea_psi': np.float64(757.473977289535),
#   'temperatura_c': np.float64(79.66191834024845),
#   'choke_percent': np.float64(43.18412997703595),
#   'horas_operativas': np.float64(23.327821172843084)},
#  {'fecha': Timestamp('2022-01-05 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1165.2026563223644),
#   'gas_mscf': np.float64(1359.5926983940637),
#   'agua_bbl': np.float64(221.4737807497676),
#   'presion_cabezal_psi': np.float64(1833.8488475897993),
#   'presion_linea_psi': np.float64(770.9738275097639),
#   'temperatura_c': np.float64(80.3006553951312),
#   'choke_percent': np.float64(50.94853083805198),
#   'horas_operativas': np.float64(23.92427013953783)},
#  {'fecha': Timestamp('2022-01-06 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1163.535743152876),
#   'gas_mscf': np.float64(1397.4684004963983),
#   'agua_bbl': np.float64(210.56590372108832),
#   'presion_cabezal_psi': np.float64(1898.8010109859651),
#   'presion_linea_psi': np.float64(829.4289202210305),
#   'temperatura_c': np.float64(83.79896651249513),
#   'choke_percent': np.float64(46.69008911101695),
#   'horas_operativas': np.float64(21.986104047707464)},
#  {'fecha': Timestamp('2022-01-07 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1379.4711665509758),
#   'gas_mscf': np.float64(1680.2653144234434),
#   'agua_bbl': np.float64(206.45808300680048),
#   'presion_cabezal_psi': np.float64(1509.174462180631),
#   'presion_linea_psi': np.float64(883.4952252175704),
#   'temperatura_c': np.float64(81.4753857486598),
#   'choke_percent': np.float64(52.12943603096518),
#   'horas_operativas': np.float64(23.08568716140336)},
#  {'fecha': Timestamp('2022-01-08 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1280.3935776332394),
#   'gas_mscf': np.float64(1609.0294735496393),
#   'agua_bbl': np.float64(221.21509070109667),
#   'presion_cabezal_psi': np.float64(2007.4374704780726),
#   'presion_linea_psi': np.float64(819.733576491149),
#   'temperatura_c': np.float64(85.12630730426429),
#   'choke_percent': np.float64(50.09573888707876),
#   'horas_operativas': np.float64(22.074575373940412)},
#  {'fecha': Timestamp('2022-01-09 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1130.3025927493447),
#   'gas_mscf': np.float64(1404.326652603474),
#   'agua_bbl': np.float64(235.09479134322106),
#   'presion_cabezal_psi': np.float64(1784.4410371844826),
#   'presion_linea_psi': np.float64(740.2058468982408),
#   'temperatura_c': np.float64(81.84745714234892),
#   'choke_percent': np.float64(46.792565454778455),
#   'horas_operativas': np.float64(23.255383755674316)},
#  {'fecha': Timestamp('2022-01-10 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1250.087157445266),
#   'gas_mscf': np.float64(1607.7637118098971),
#   'agua_bbl': np.float64(222.2969841926936),
#   'presion_cabezal_psi': np.float64(1909.0182816737517),
#   'presion_linea_psi': np.float64(822.230133411007),
#   'temperatura_c': np.float64(77.40073958879066),
#   'choke_percent': np.float64(52.43936142435537),
#   'horas_operativas': np.float64(22.104653677636975)},
#  {'fecha': Timestamp('2022-01-11 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1127.712583207097),
#   'gas_mscf': np.float64(1314.8877217041138),
#   'agua_bbl': np.float64(165.41662798740384),
#   'presion_cabezal_psi': np.float64(1694.009407287447),
#   'presion_linea_psi': np.float64(859.8315743322826),
#   'temperatura_c': np.float64(82.32139705857493),
#   'choke_percent': np.float64(59.021740548933714),
#   'horas_operativas': np.float64(22.59189916083978)},
#  {'fecha': Timestamp('2022-01-12 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1125.7802077760489),
#   'gas_mscf': np.float64(1394.5522811672924),
#   'agua_bbl': np.float64(176.8673525614464),
#   'presion_cabezal_psi': np.float64(1859.077390506257),
#   'presion_linea_psi': np.float64(769.5108547840309),
#   'temperatura_c': np.float64(74.84604909292642),
#   'choke_percent': np.float64(49.04548104136351),
#   'horas_operativas': np.float64(22.004184605209772)},
#  {'fecha': Timestamp('2022-01-13 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1209.0506371410893),
#   'gas_mscf': np.float64(1460.0278648562246),
#   'agua_bbl': np.float64(190.18754946217004),
#   'presion_cabezal_psi': np.float64(1692.2584436826344),
#   'presion_linea_psi': np.float64(793.2991416663541),
#   'temperatura_c': np.float64(81.15811202848847),
#   'choke_percent': np.float64(53.59878971074091),
#   'horas_operativas': np.float64(23.651136241823657)},
#  {'fecha': Timestamp('2022-01-14 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(948.7712327948007),
#   'gas_mscf': np.float64(1248.0156260146443),
#   'agua_bbl': np.float64(203.43102125571275),
#   'presion_cabezal_psi': np.float64(1735.0231039304197),
#   'presion_linea_psi': np.float64(800.7344097364598),
#   'temperatura_c': np.float64(80.4996145857902),
#   'choke_percent': np.float64(43.53363521064418),
#   'horas_operativas': np.float64(23.858451116656667)},
#  {'fecha': Timestamp('2022-01-15 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(969.7267278722434),
#   'gas_mscf': np.float64(1123.2571591789344),
#   'agua_bbl': np.float64(213.48791028977888),
#   'presion_cabezal_psi': np.float64(1988.6031353866786),
#   'presion_linea_psi': np.float64(760.755084345888),
#   'temperatura_c': np.float64(79.67543401165514),
#   'choke_percent': np.float64(45.21781811590996),
#   'horas_operativas': np.float64(22.765379430042586)},
#  {'fecha': Timestamp('2022-01-16 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1107.5966746765955),
#   'gas_mscf': np.float64(1287.1299175028757),
#   'agua_bbl': np.float64(188.8456339180227),
#   'presion_cabezal_psi': np.float64(1777.9317599236654),
#   'presion_linea_psi': np.float64(832.4140216921929),
#   'temperatura_c': np.float64(80.12337232815392),
#   'choke_percent': np.float64(52.362031389401885),
#   'horas_operativas': np.float64(23.038237994960028)},
#  {'fecha': Timestamp('2022-01-17 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1051.8880557253694),
#   'gas_mscf': np.float64(1232.2960345982422),
#   'agua_bbl': np.float64(207.32187672174135),
#   'presion_cabezal_psi': np.float64(1818.5432873179723),
#   'presion_linea_psi': np.float64(793.9525925696109),
#   'temperatura_c': np.float64(71.40662924511412),
#   'choke_percent': np.float64(57.420580142679825),
#   'horas_operativas': np.float64(21.551408585366456)},
#  {'fecha': Timestamp('2022-01-18 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1209.4963804063611),
#   'gas_mscf': np.float64(1345.200870272143),
#   'agua_bbl': np.float64(188.70516526557972),
#   'presion_cabezal_psi': np.float64(1883.6067730688753),
#   'presion_linea_psi': np.float64(820.9766221953514),
#   'temperatura_c': np.float64(78.12182275993702),
#   'choke_percent': np.float64(51.7780667439283),
#   'horas_operativas': np.float64(22.700323351993212)},
#  {'fecha': Timestamp('2022-01-19 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1061.1850168969095),
#   'gas_mscf': np.float64(1247.1342691922532),
#   'agua_bbl': np.float64(191.80900184182877),
#   'presion_cabezal_psi': np.float64(1845.9681887972606),
#   'presion_linea_psi': np.float64(755.625391109895),
#   'temperatura_c': np.float64(81.37898817967444),
#   'choke_percent': np.float64(48.43470984738423),
#   'horas_operativas': np.float64(22.949795382958253)},
#  {'fecha': Timestamp('2022-01-20 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(999.0349591889991),
#   'gas_mscf': np.float64(1160.8853179491139),
#   'agua_bbl': np.float64(176.13292174184687),
#   'presion_cabezal_psi': np.float64(1811.2418905143577),
#   'presion_linea_psi': np.float64(778.1270849838295),
#   'temperatura_c': np.float64(81.76309094506409),
#   'choke_percent': np.float64(49.99645702711677),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-01-21 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1342.7550417294954),
#   'gas_mscf': np.float64(1618.8257393992046),
#   'agua_bbl': np.float64(186.02851660171643),
#   'presion_cabezal_psi': np.float64(1832.4961002466225),
#   'presion_linea_psi': np.float64(836.1190678913886),
#   'temperatura_c': np.float64(75.87419299415255),
#   'choke_percent': np.float64(43.74796133015141),
#   'horas_operativas': np.float64(21.888032974225837)},
#  {'fecha': Timestamp('2022-01-22 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1138.152105029221),
#   'gas_mscf': np.float64(1382.8703248239233),
#   'agua_bbl': np.float64(177.6867796048794),
#   'presion_cabezal_psi': np.float64(2036.1415585238274),
#   'presion_linea_psi': np.float64(781.3583423954117),
#   'temperatura_c': np.float64(87.38956757085262),
#   'choke_percent': np.float64(53.022576631776836),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-01-23 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1171.7189996014768),
#   'gas_mscf': np.float64(1499.8713414825665),
#   'agua_bbl': np.float64(185.43054947955932),
#   'presion_cabezal_psi': np.float64(1789.8381202966414),
#   'presion_linea_psi': np.float64(886.3481925616702),
#   'temperatura_c': np.float64(76.77829938759952),
#   'choke_percent': np.float64(54.41166531161704),
#   'horas_operativas': np.float64(23.996858773465807)},
#  {'fecha': Timestamp('2022-01-24 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(991.0184657753285),
#   'gas_mscf': np.float64(1236.7433508396969),
#   'agua_bbl': np.float64(226.2486462025828),
#   'presion_cabezal_psi': np.float64(1815.5099046714968),
#   'presion_linea_psi': np.float64(780.0181907192699),
#   'temperatura_c': np.float64(86.0042762213645),
#   'choke_percent': np.float64(47.7395483358346),
#   'horas_operativas': np.float64(23.280636404490135)},
#  {'fecha': Timestamp('2022-01-25 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1095.0372302031728),
#   'gas_mscf': np.float64(1285.199493460687),
#   'agua_bbl': np.float64(186.41588141563128),
#   'presion_cabezal_psi': np.float64(1900.2654396007613),
#   'presion_linea_psi': np.float64(811.2342362875943),
#   'temperatura_c': np.float64(83.34043577697635),
#   'choke_percent': np.float64(47.64978926120249),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-01-26 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1172.0510496968584),
#   'gas_mscf': np.float64(1361.5405260688121),
#   'agua_bbl': np.float64(258.27980288280247),
#   'presion_cabezal_psi': np.float64(1905.5525932957985),
#   'presion_linea_psi': np.float64(846.6295415936545),
#   'temperatura_c': np.float64(78.02044425861793),
#   'choke_percent': np.float64(51.32939114826024),
#   'horas_operativas': np.float64(23.37210547260686)},
#  {'fecha': Timestamp('2022-01-27 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1019.0005610081524),
#   'gas_mscf': np.float64(1247.3966317851082),
#   'agua_bbl': np.float64(215.72707575112653),
#   'presion_cabezal_psi': np.float64(1913.5030305560379),
#   'presion_linea_psi': np.float64(729.0817133533484),
#   'temperatura_c': np.float64(90.17488124069885),
#   'choke_percent': np.float64(47.81640131979702),
#   'horas_operativas': np.float64(23.38915919566793)},
#  {'fecha': Timestamp('2022-01-28 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1200.5852702750296),
#   'gas_mscf': np.float64(1374.6906639790034),
#   'agua_bbl': np.float64(209.78625039057212),
#   'presion_cabezal_psi': np.float64(1858.4730222029184),
#   'presion_linea_psi': np.float64(711.9595594009612),
#   'temperatura_c': np.float64(75.37650386643882),
#   'choke_percent': np.float64(49.66933692687089),
#   'horas_operativas': np.float64(22.946879346982456)},
#  {'fecha': Timestamp('2022-01-29 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1081.80884629591),
#   'gas_mscf': np.float64(1389.7435538478096),
#   'agua_bbl': np.float64(189.15143681428384),
#   'presion_cabezal_psi': np.float64(1680.0995087269516),
#   'presion_linea_psi': np.float64(723.7171842714953),
#   'temperatura_c': np.float64(85.98642168075857),
#   'choke_percent': np.float64(60.49860894583258),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-01-30 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1117.2684801962512),
#   'gas_mscf': np.float64(1399.6941822715658),
#   'agua_bbl': np.float64(220.5541091080585),
#   'presion_cabezal_psi': np.float64(1957.5431532301097),
#   'presion_linea_psi': np.float64(863.1292051713591),
#   'temperatura_c': np.float64(86.43911311056226),
#   'choke_percent': np.float64(48.76487149627002),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-01-31 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1078.4554347010455),
#   'gas_mscf': np.float64(1270.6877390360194),
#   'agua_bbl': np.float64(195.2647289808147),
#   'presion_cabezal_psi': np.float64(1679.3654606981313),
#   'presion_linea_psi': np.float64(772.4070927053776),
#   'temperatura_c': np.float64(78.1282256050967),
#   'choke_percent': np.float64(48.20829923989389),
#   'horas_operativas': np.float64(22.374322712503787)},
#  {'fecha': Timestamp('2022-02-01 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1371.324362062236),
#   'gas_mscf': np.float64(1559.9325080201395),
#   'agua_bbl': np.float64(209.4475109511881),
#   'presion_cabezal_psi': np.float64(1824.0635465239034),
#   'presion_linea_psi': np.float64(927.9099642834126),
#   'temperatura_c': np.float64(88.48833933187795),
#   'choke_percent': np.float64(46.76229097182421),
#   'horas_operativas': np.float64(21.680752805401234)},
#  {'fecha': Timestamp('2022-02-02 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1145.824315308689),
#   'gas_mscf': np.float64(1442.6827970786974),
#   'agua_bbl': np.float64(258.43909002699985),
#   'presion_cabezal_psi': np.float64(1718.1724149980641),
#   'presion_linea_psi': np.float64(771.7876200671305),
#   'temperatura_c': np.float64(80.32001424910189),
#   'choke_percent': np.float64(53.720959857499686),
#   'horas_operativas': np.float64(22.797019362604342)},
#  {'fecha': Timestamp('2022-02-03 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1018.9139206145308),
#   'gas_mscf': np.float64(1216.969712474806),
#   'agua_bbl': np.float64(205.5465416050349),
#   'presion_cabezal_psi': np.float64(1786.9861653407008),
#   'presion_linea_psi': np.float64(809.2275651598518),
#   'temperatura_c': np.float64(83.05748366101419),
#   'choke_percent': np.float64(49.09387913390948),
#   'horas_operativas': np.float64(22.199961435602354)},
#  {'fecha': Timestamp('2022-02-04 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1242.942115666375),
#   'gas_mscf': np.float64(1553.421354398323),
#   'agua_bbl': np.float64(230.68380248195007),
#   'presion_cabezal_psi': np.float64(1826.076241030348),
#   'presion_linea_psi': np.float64(877.1054976283938),
#   'temperatura_c': np.float64(82.95891513335897),
#   'choke_percent': np.float64(46.75313480839287),
#   'horas_operativas': np.float64(22.936475425384646)},
#  {'fecha': Timestamp('2022-02-05 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(996.1352235162101),
#   'gas_mscf': np.float64(1115.6408852797338),
#   'agua_bbl': np.float64(193.8656601137922),
#   'presion_cabezal_psi': np.float64(1825.1357215450273),
#   'presion_linea_psi': np.float64(900.3046444079562),
#   'temperatura_c': np.float64(81.02856156152062),
#   'choke_percent': np.float64(56.60652016136506),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-02-06 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1166.1020662516514),
#   'gas_mscf': np.float64(1369.353728354293),
#   'agua_bbl': np.float64(207.46052805468503),
#   'presion_cabezal_psi': np.float64(1834.9920754235284),
#   'presion_linea_psi': np.float64(903.0751788318199),
#   'temperatura_c': np.float64(85.7964421861603),
#   'choke_percent': np.float64(57.098015022568184),
#   'horas_operativas': np.float64(22.54269834491321)},
#  {'fecha': Timestamp('2022-02-07 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(904.2822282334687),
#   'gas_mscf': np.float64(1085.4008588660715),
#   'agua_bbl': np.float64(243.80767669908246),
#   'presion_cabezal_psi': np.float64(1953.9711269058646),
#   'presion_linea_psi': np.float64(860.4183115296571),
#   'temperatura_c': np.float64(85.75162366364336),
#   'choke_percent': np.float64(46.99788217130647),
#   'horas_operativas': np.float64(22.957176618688425)},
#  {'fecha': Timestamp('2022-02-08 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(978.4667572631852),
#   'gas_mscf': np.float64(1176.5091384040593),
#   'agua_bbl': np.float64(196.0839461113085),
#   'presion_cabezal_psi': np.float64(1837.753430151398),
#   'presion_linea_psi': np.float64(851.2031262905731),
#   'temperatura_c': np.float64(73.08277074415447),
#   'choke_percent': np.float64(40.66730024319692),
#   'horas_operativas': np.float64(23.058022734808397)},
#  {'fecha': Timestamp('2022-02-09 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1159.8811001299946),
#   'gas_mscf': np.float64(1369.3540465820313),
#   'agua_bbl': np.float64(245.1041391524648),
#   'presion_cabezal_psi': np.float64(1767.7843364709352),
#   'presion_linea_psi': np.float64(829.6263474600592),
#   'temperatura_c': np.float64(88.38784145971336),
#   'choke_percent': np.float64(55.03756844918461),
#   'horas_operativas': np.float64(23.848430882205285)},
#  {'fecha': Timestamp('2022-02-10 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1223.2846356657178),
#   'gas_mscf': np.float64(1499.0840594162362),
#   'agua_bbl': np.float64(223.2423451580137),
#   'presion_cabezal_psi': np.float64(1888.4087168288356),
#   'presion_linea_psi': np.float64(838.9180538083319),
#   'temperatura_c': np.float64(73.59383696249216),
#   'choke_percent': np.float64(46.57685087119998),
#   'horas_operativas': np.float64(20.753110666015395)},
#  {'fecha': Timestamp('2022-02-11 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1153.6459564829777),
#   'gas_mscf': np.float64(1330.9941263104433),
#   'agua_bbl': np.float64(198.07036740477525),
#   'presion_cabezal_psi': np.float64(1910.747048892464),
#   'presion_linea_psi': np.float64(772.4407141835733),
#   'temperatura_c': np.float64(87.10861970481322),
#   'choke_percent': np.float64(53.953127995813844),
#   'horas_operativas': np.float64(22.393299705234703)},
#  {'fecha': Timestamp('2022-02-12 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1117.619304852679),
#   'gas_mscf': np.float64(1334.0241915721501),
#   'agua_bbl': np.float64(222.2005124816872),
#   'presion_cabezal_psi': np.float64(1668.8392184863008),
#   'presion_linea_psi': np.float64(759.0900558288846),
#   'temperatura_c': np.float64(87.61842953886476),
#   'choke_percent': np.float64(40.14948091144082),
#   'horas_operativas': np.float64(23.211283692279473)},
#  {'fecha': Timestamp('2022-02-13 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1093.7822074889918),
#   'gas_mscf': np.float64(1318.553430572385),
#   'agua_bbl': np.float64(229.2363600622875),
#   'presion_cabezal_psi': np.float64(1851.1400069849858),
#   'presion_linea_psi': np.float64(799.8312771294524),
#   'temperatura_c': np.float64(76.56849870542284),
#   'choke_percent': np.float64(54.462986691496546),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-02-14 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(950.9117774579236),
#   'gas_mscf': np.float64(1166.8160746524459),
#   'agua_bbl': np.float64(222.45464256195183),
#   'presion_cabezal_psi': np.float64(1861.3172742310899),
#   'presion_linea_psi': np.float64(791.4907688737536),
#   'temperatura_c': np.float64(80.00708686189807),
#   'choke_percent': np.float64(43.9441403535961),
#   'horas_operativas': np.float64(22.508097552493794)},
#  {'fecha': Timestamp('2022-02-15 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1040.3750866636813),
#   'gas_mscf': np.float64(1284.030847900862),
#   'agua_bbl': np.float64(178.84738033407146),
#   'presion_cabezal_psi': np.float64(1761.2436496640007),
#   'presion_linea_psi': np.float64(777.3385975336363),
#   'temperatura_c': np.float64(76.56985163872527),
#   'choke_percent': np.float64(53.653820595332625),
#   'horas_operativas': np.float64(21.123447293958126)},
#  {'fecha': Timestamp('2022-02-16 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1069.903921460808),
#   'gas_mscf': np.float64(1227.6526011610763),
#   'agua_bbl': np.float64(195.94282208413188),
#   'presion_cabezal_psi': np.float64(1928.370681331162),
#   'presion_linea_psi': np.float64(834.8193723728358),
#   'temperatura_c': np.float64(81.06036471540165),
#   'choke_percent': np.float64(50.07136533918217),
#   'horas_operativas': np.float64(23.619711445966136)},
#  {'fecha': Timestamp('2022-02-17 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1250.461627276598),
#   'gas_mscf': np.float64(1423.8482441951364),
#   'agua_bbl': np.float64(205.76914350120248),
#   'presion_cabezal_psi': np.float64(1775.5944412967472),
#   'presion_linea_psi': np.float64(847.7652604285255),
#   'temperatura_c': np.float64(80.63076069395903),
#   'choke_percent': np.float64(45.23030290301678),
#   'horas_operativas': np.float64(22.36463761117437)},
#  {'fecha': Timestamp('2022-02-18 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1163.269741800119),
#   'gas_mscf': np.float64(1459.8075312550682),
#   'agua_bbl': np.float64(209.46505827338876),
#   'presion_cabezal_psi': np.float64(1802.9576453471543),
#   'presion_linea_psi': np.float64(804.4203443145924),
#   'temperatura_c': np.float64(86.10455373023866),
#   'choke_percent': np.float64(47.9648184353661),
#   'horas_operativas': np.float64(21.81033334090964)},
#  {'fecha': Timestamp('2022-02-19 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(908.9015130193129),
#   'gas_mscf': np.float64(1107.297516222155),
#   'agua_bbl': np.float64(223.60163977013414),
#   'presion_cabezal_psi': np.float64(1772.892817571613),
#   'presion_linea_psi': np.float64(873.876504052763),
#   'temperatura_c': np.float64(88.7924599936877),
#   'choke_percent': np.float64(53.431592284783505),
#   'horas_operativas': np.float64(22.375654610286777)},
#  {'fecha': Timestamp('2022-02-20 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1157.7893872169518),
#   'gas_mscf': np.float64(1351.9229378325144),
#   'agua_bbl': np.float64(214.9769494114316),
#   'presion_cabezal_psi': np.float64(1791.5579047581468),
#   'presion_linea_psi': np.float64(742.9155442933247),
#   'temperatura_c': np.float64(89.25333647938547),
#   'choke_percent': np.float64(50.529472265576175),
#   'horas_operativas': np.float64(22.81547464234415)},
#  {'fecha': Timestamp('2022-02-21 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1071.124608012886),
#   'gas_mscf': np.float64(1362.9071283915891),
#   'agua_bbl': np.float64(184.9510346917883),
#   'presion_cabezal_psi': np.float64(1680.1724913104797),
#   'presion_linea_psi': np.float64(790.3170270360141),
#   'temperatura_c': np.float64(79.4974043477603),
#   'choke_percent': np.float64(52.92206490236242),
#   'horas_operativas': np.float64(22.395255335461787)},
#  {'fecha': Timestamp('2022-02-22 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1034.5412008809558),
#   'gas_mscf': np.float64(1247.23317277179),
#   'agua_bbl': np.float64(219.49713254889608),
#   'presion_cabezal_psi': np.float64(1645.5949117405705),
#   'presion_linea_psi': np.float64(764.1588839698597),
#   'temperatura_c': np.float64(81.29477818448969),
#   'choke_percent': np.float64(59.88220292257743),
#   'horas_operativas': np.float64(20.79443394290093)},
#  {'fecha': Timestamp('2022-02-23 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1187.6125402542755),
#   'gas_mscf': np.float64(1484.0999075083218),
#   'agua_bbl': np.float64(224.34040557710964),
#   'presion_cabezal_psi': np.float64(1948.8505063224973),
#   'presion_linea_psi': np.float64(706.673169146347),
#   'temperatura_c': np.float64(73.95564600916558),
#   'choke_percent': np.float64(42.17879194144474),
#   'horas_operativas': np.float64(23.89706619688713)},
#  {'fecha': Timestamp('2022-02-24 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1236.3730553330527),
#   'gas_mscf': np.float64(1487.0235904701685),
#   'agua_bbl': np.float64(223.56027654320988),
#   'presion_cabezal_psi': np.float64(1704.5038651681673),
#   'presion_linea_psi': np.float64(795.865965707865),
#   'temperatura_c': np.float64(78.37473293204309),
#   'choke_percent': np.float64(58.08606287484312),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-02-25 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1222.8506332799857),
#   'gas_mscf': np.float64(1570.4581561800821),
#   'agua_bbl': np.float64(234.21612107028986),
#   'presion_cabezal_psi': np.float64(1689.8607650543693),
#   'presion_linea_psi': np.float64(793.9126245808358),
#   'temperatura_c': np.float64(87.25887534250937),
#   'choke_percent': np.float64(50.52177968761607),
#   'horas_operativas': np.float64(23.651521991339507)},
#  {'fecha': Timestamp('2022-02-26 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1008.8369988163015),
#   'gas_mscf': np.float64(1298.3714407017221),
#   'agua_bbl': np.float64(229.5152509775125),
#   'presion_cabezal_psi': np.float64(1573.4609886396286),
#   'presion_linea_psi': np.float64(875.6724871621066),
#   'temperatura_c': np.float64(90.5423437776484),
#   'choke_percent': np.float64(45.50607975838436),
#   'horas_operativas': np.float64(21.862314329575185)},
#  {'fecha': Timestamp('2022-02-27 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1070.8858723387214),
#   'gas_mscf': np.float64(1272.614839382512),
#   'agua_bbl': np.float64(222.2569734427687),
#   'presion_cabezal_psi': np.float64(1724.7038252310497),
#   'presion_linea_psi': np.float64(831.5405842277389),
#   'temperatura_c': np.float64(76.32176751969781),
#   'choke_percent': np.float64(43.34843187130505),
#   'horas_operativas': np.float64(22.798508466052482)},
#  {'fecha': Timestamp('2022-02-28 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1146.1933952286727),
#   'gas_mscf': np.float64(1424.010621822125),
#   'agua_bbl': np.float64(211.90688453694523),
#   'presion_cabezal_psi': np.float64(1656.0910206592503),
#   'presion_linea_psi': np.float64(748.7906587835398),
#   'temperatura_c': np.float64(79.55953392113896),
#   'choke_percent': np.float64(49.054398046114834),
#   'horas_operativas': np.float64(22.99347868477054)},
#  {'fecha': Timestamp('2022-03-01 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1221.9597918807422),
#   'gas_mscf': np.float64(1498.6205477361477),
#   'agua_bbl': np.float64(180.32807023221767),
#   'presion_cabezal_psi': np.float64(1952.4015160136369),
#   'presion_linea_psi': np.float64(892.7046283167094),
#   'temperatura_c': np.float64(82.41742248978794),
#   'choke_percent': np.float64(54.6082505596223),
#   'horas_operativas': np.float64(23.59879438956191)},
#  {'fecha': Timestamp('2022-03-02 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1045.8482253660259),
#   'gas_mscf': np.float64(1323.4494483158485),
#   'agua_bbl': np.float64(222.37700694268312),
#   'presion_cabezal_psi': np.float64(1888.9817089342635),
#   'presion_linea_psi': np.float64(861.0516847762676),
#   'temperatura_c': np.float64(83.97709766892544),
#   'choke_percent': np.float64(49.36225439811233),
#   'horas_operativas': np.float64(23.66834048871808)},
#  {'fecha': Timestamp('2022-03-03 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1079.5269750781827),
#   'gas_mscf': np.float64(1247.186197064814),
#   'agua_bbl': np.float64(218.17601377476063),
#   'presion_cabezal_psi': np.float64(1718.9849654822276),
#   'presion_linea_psi': np.float64(829.1048851734308),
#   'temperatura_c': np.float64(78.55435146458056),
#   'choke_percent': np.float64(57.55577465123674),
#   'horas_operativas': np.float64(22.265826201221504)},
#  {'fecha': Timestamp('2022-03-04 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(967.5049318340988),
#   'gas_mscf': np.float64(1195.3084912008405),
#   'agua_bbl': np.float64(219.69171835407002),
#   'presion_cabezal_psi': np.float64(2012.8435805344307),
#   'presion_linea_psi': np.float64(788.6757950575084),
#   'temperatura_c': np.float64(84.74798033775318),
#   'choke_percent': np.float64(42.744121549742204),
#   'horas_operativas': np.float64(23.08199555641356)},
#  {'fecha': Timestamp('2022-03-05 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(955.1815653105747),
#   'gas_mscf': np.float64(1199.139102715169),
#   'agua_bbl': np.float64(188.96331607316773),
#   'presion_cabezal_psi': np.float64(1885.5765486991595),
#   'presion_linea_psi': np.float64(752.0280381638261),
#   'temperatura_c': np.float64(80.28300579447551),
#   'choke_percent': np.float64(49.93955526076973),
#   'horas_operativas': np.float64(23.45728040461524)},
#  {'fecha': Timestamp('2022-03-06 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1194.692842407515),
#   'gas_mscf': np.float64(1345.694436567862),
#   'agua_bbl': np.float64(193.1155674554435),
#   'presion_cabezal_psi': np.float64(1754.7168616491379),
#   'presion_linea_psi': np.float64(781.3896611964474),
#   'temperatura_c': np.float64(82.60368268498725),
#   'choke_percent': np.float64(43.73803277793441),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-03-07 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1258.4040796934755),
#   'gas_mscf': np.float64(1450.9219699988819),
#   'agua_bbl': np.float64(236.03843099312803),
#   'presion_cabezal_psi': np.float64(1537.0594285126426),
#   'presion_linea_psi': np.float64(854.4374309852093),
#   'temperatura_c': np.float64(85.43031384897522),
#   'choke_percent': np.float64(51.81815941312484),
#   'horas_operativas': np.float64(23.704506539824724)},
#  {'fecha': Timestamp('2022-03-08 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1085.4817402394071),
#   'gas_mscf': np.float64(1200.6164793992834),
#   'agua_bbl': np.float64(214.42321179555444),
#   'presion_cabezal_psi': np.float64(2015.894257259074),
#   'presion_linea_psi': np.float64(894.2293152967304),
#   'temperatura_c': np.float64(82.7531527874626),
#   'choke_percent': np.float64(54.4344369504865),
#   'horas_operativas': np.float64(23.78905668737552)},
#  {'fecha': Timestamp('2022-03-09 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1213.0167241581642),
#   'gas_mscf': np.float64(1442.149727267569),
#   'agua_bbl': np.float64(229.0835353445712),
#   'presion_cabezal_psi': np.float64(1647.6427533236404),
#   'presion_linea_psi': np.float64(877.1621764136095),
#   'temperatura_c': np.float64(80.56045451192315),
#   'choke_percent': np.float64(47.89619103159473),
#   'horas_operativas': np.float64(23.083826627929362)},
#  {'fecha': Timestamp('2022-03-10 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1134.4610610198117),
#   'gas_mscf': np.float64(1397.2303860135721),
#   'agua_bbl': np.float64(216.25936131755773),
#   'presion_cabezal_psi': np.float64(1621.860125304311),
#   'presion_linea_psi': np.float64(775.5575289106863),
#   'temperatura_c': np.float64(82.21486484352074),
#   'choke_percent': np.float64(36.978930716864326),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-03-11 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1012.1244660924433),
#   'gas_mscf': np.float64(1289.6672119157333),
#   'agua_bbl': np.float64(216.52785515160502),
#   'presion_cabezal_psi': np.float64(1888.457043200964),
#   'presion_linea_psi': np.float64(744.0191283355495),
#   'temperatura_c': np.float64(82.34081025471092),
#   'choke_percent': np.float64(50.994740733982475),
#   'horas_operativas': np.float64(23.409762795959498)},
#  {'fecha': Timestamp('2022-03-12 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1131.382541976292),
#   'gas_mscf': np.float64(1361.363789392539),
#   'agua_bbl': np.float64(234.9384135127049),
#   'presion_cabezal_psi': np.float64(2029.9752406339273),
#   'presion_linea_psi': np.float64(807.0443123455602),
#   'temperatura_c': np.float64(80.95145653705814),
#   'choke_percent': np.float64(52.18369275866755),
#   'horas_operativas': np.float64(22.13891208982643)},
#  {'fecha': Timestamp('2022-03-13 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1271.057821016138),
#   'gas_mscf': np.float64(1606.70016249793),
#   'agua_bbl': np.float64(206.09211462125606),
#   'presion_cabezal_psi': np.float64(1924.2272818510517),
#   'presion_linea_psi': np.float64(711.5780317218574),
#   'temperatura_c': np.float64(81.52558786049018),
#   'choke_percent': np.float64(52.02147377480849),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-03-14 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1080.6748001463097),
#   'gas_mscf': np.float64(1227.8046872648272),
#   'agua_bbl': np.float64(218.57596357426507),
#   'presion_cabezal_psi': np.float64(1841.990912005236),
#   'presion_linea_psi': np.float64(816.158385709239),
#   'temperatura_c': np.float64(90.83002501480502),
#   'choke_percent': np.float64(56.17891095911077),
#   'horas_operativas': np.float64(23.697903272539026)},
#  {'fecha': Timestamp('2022-03-15 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1271.2137804346055),
#   'gas_mscf': np.float64(1440.2874145537687),
#   'agua_bbl': np.float64(207.64884846543882),
#   'presion_cabezal_psi': np.float64(1844.8754341665287),
#   'presion_linea_psi': np.float64(792.6198706850665),
#   'temperatura_c': np.float64(85.65776678859166),
#   'choke_percent': np.float64(44.644731601754756),
#   'horas_operativas': np.float64(22.556955978871517)},
#  {'fecha': Timestamp('2022-03-16 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(767.5718682696727),
#   'gas_mscf': np.float64(918.3088569787762),
#   'agua_bbl': np.float64(208.4455035463991),
#   'presion_cabezal_psi': np.float64(1870.5415558780307),
#   'presion_linea_psi': np.float64(776.6981749065878),
#   'temperatura_c': np.float64(81.39130288962991),
#   'choke_percent': np.float64(53.40108052725225),
#   'horas_operativas': np.float64(22.520507032600758)},
#  {'fecha': Timestamp('2022-03-17 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1179.0564394671972),
#   'gas_mscf': np.float64(1434.070999807602),
#   'agua_bbl': np.float64(211.19332743007917),
#   'presion_cabezal_psi': np.float64(1860.8928589786765),
#   'presion_linea_psi': np.float64(720.2648466366602),
#   'temperatura_c': np.float64(86.36816137417058),
#   'choke_percent': np.float64(55.962537562389876),
#   'horas_operativas': np.float64(23.29657554514076)},
#  {'fecha': Timestamp('2022-03-18 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1089.3627615069558),
#   'gas_mscf': np.float64(1305.6005764036422),
#   'agua_bbl': np.float64(222.06105538325357),
#   'presion_cabezal_psi': np.float64(1812.9191423969376),
#   'presion_linea_psi': np.float64(825.6800053284858),
#   'temperatura_c': np.float64(81.22812236418451),
#   'choke_percent': np.float64(41.10706207996742),
#   'horas_operativas': np.float64(23.463184795267583)},
#  {'fecha': Timestamp('2022-03-19 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1041.5273188735628),
#   'gas_mscf': np.float64(1146.4606776462815),
#   'agua_bbl': np.float64(208.2852861133089),
#   'presion_cabezal_psi': np.float64(1795.0201103951874),
#   'presion_linea_psi': np.float64(773.3649580169044),
#   'temperatura_c': np.float64(88.77581495348772),
#   'choke_percent': np.float64(51.59825912959489),
#   'horas_operativas': np.float64(23.197292265631205)},
#  {'fecha': Timestamp('2022-03-20 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1086.9126920042547),
#   'gas_mscf': np.float64(1299.8392284294664),
#   'agua_bbl': np.float64(243.21752849740218),
#   'presion_cabezal_psi': np.float64(1778.1406872100479),
#   'presion_linea_psi': np.float64(741.5041582144856),
#   'temperatura_c': np.float64(84.77051232650773),
#   'choke_percent': np.float64(47.47910084496164),
#   'horas_operativas': np.float64(23.311308673442884)},
#  {'fecha': Timestamp('2022-03-21 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(835.8884342865337),
#   'gas_mscf': np.float64(937.8426461185976),
#   'agua_bbl': np.float64(200.45267652306336),
#   'presion_cabezal_psi': np.float64(1708.8035411133324),
#   'presion_linea_psi': np.float64(656.3868893359175),
#   'temperatura_c': np.float64(82.39703430449583),
#   'choke_percent': np.float64(49.592386634491774),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-03-22 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1046.5334870977144),
#   'gas_mscf': np.float64(1289.3238119587593),
#   'agua_bbl': np.float64(214.85007570706267),
#   'presion_cabezal_psi': np.float64(1755.9324923133227),
#   'presion_linea_psi': np.float64(798.6242547474682),
#   'temperatura_c': np.float64(85.18250403986622),
#   'choke_percent': np.float64(51.73838241769168),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-03-23 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1114.2471332570617),
#   'gas_mscf': np.float64(1355.4264722133164),
#   'agua_bbl': np.float64(210.03584318843608),
#   'presion_cabezal_psi': np.float64(1614.5043185804614),
#   'presion_linea_psi': np.float64(888.6125798334872),
#   'temperatura_c': np.float64(75.09904068991378),
#   'choke_percent': np.float64(47.56385717943224),
#   'horas_operativas': np.float64(23.190635591265025)},
#  {'fecha': Timestamp('2022-03-24 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1247.2425195809788),
#   'gas_mscf': np.float64(1449.6970341808067),
#   'agua_bbl': np.float64(248.01324784522907),
#   'presion_cabezal_psi': np.float64(1773.766037320525),
#   'presion_linea_psi': np.float64(883.0629607273935),
#   'temperatura_c': np.float64(77.32821098263294),
#   'choke_percent': np.float64(46.62145960419194),
#   'horas_operativas': np.float64(23.94131058076748)},
#  {'fecha': Timestamp('2022-03-25 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1006.2065131195711),
#   'gas_mscf': np.float64(1181.7544698766505),
#   'agua_bbl': np.float64(223.24828183337075),
#   'presion_cabezal_psi': np.float64(1684.5408892849084),
#   'presion_linea_psi': np.float64(777.1451871706864),
#   'temperatura_c': np.float64(77.00017245326679),
#   'choke_percent': np.float64(50.170762087440124),
#   'horas_operativas': np.float64(21.96747609647246)},
#  {'fecha': Timestamp('2022-03-26 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(969.885504698968),
#   'gas_mscf': np.float64(1110.901929544314),
#   'agua_bbl': np.float64(240.1978438787252),
#   'presion_cabezal_psi': np.float64(1672.8410682784229),
#   'presion_linea_psi': np.float64(769.889396981911),
#   'temperatura_c': np.float64(83.69138210207232),
#   'choke_percent': np.float64(44.563770305685985),
#   'horas_operativas': np.float64(23.39792704994681)},
#  {'fecha': Timestamp('2022-03-27 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1005.2017792564394),
#   'gas_mscf': np.float64(1203.1081802440688),
#   'agua_bbl': np.float64(190.09378335686716),
#   'presion_cabezal_psi': np.float64(1800.9894151153478),
#   'presion_linea_psi': np.float64(823.4387128037512),
#   'temperatura_c': np.float64(91.6452287181073),
#   'choke_percent': np.float64(44.57087435557408),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-03-28 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1173.7708528354115),
#   'gas_mscf': np.float64(1456.2821394275554),
#   'agua_bbl': np.float64(225.39030510643363),
#   'presion_cabezal_psi': np.float64(1922.00022863446),
#   'presion_linea_psi': np.float64(750.0807280405854),
#   'temperatura_c': np.float64(94.14425771940469),
#   'choke_percent': np.float64(53.396866414782515),
#   'horas_operativas': np.float64(22.781954104607625)},
#  {'fecha': Timestamp('2022-03-29 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1101.8847899605914),
#   'gas_mscf': np.float64(1272.9754456359324),
#   'agua_bbl': np.float64(238.08649621762828),
#   'presion_cabezal_psi': np.float64(1874.4316606002312),
#   'presion_linea_psi': np.float64(815.0895949909733),
#   'temperatura_c': np.float64(86.18223042652825),
#   'choke_percent': np.float64(44.25602982420672),
#   'horas_operativas': np.float64(22.152366071380914)},
#  {'fecha': Timestamp('2022-03-30 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(997.3775713909625),
#   'gas_mscf': np.float64(1222.0554114450472),
#   'agua_bbl': np.float64(222.18441245326494),
#   'presion_cabezal_psi': np.float64(1625.3499396376824),
#   'presion_linea_psi': np.float64(838.3040139192345),
#   'temperatura_c': np.float64(85.49952863818898),
#   'choke_percent': np.float64(53.331562504546056),
#   'horas_operativas': np.float64(22.34791111140694)},
#  {'fecha': Timestamp('2022-03-31 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1121.057104899198),
#   'gas_mscf': np.float64(1318.7556449604158),
#   'agua_bbl': np.float64(242.09346468029833),
#   'presion_cabezal_psi': np.float64(1683.2371863429662),
#   'presion_linea_psi': np.float64(861.3466611942154),
#   'temperatura_c': np.float64(73.99246136295537),
#   'choke_percent': np.float64(52.31295646426975),
#   'horas_operativas': np.float64(21.910366962657612)},
#  {'fecha': Timestamp('2022-04-01 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1069.6326110647285),
#   'gas_mscf': np.float64(1243.915491664557),
#   'agua_bbl': np.float64(210.68348513934458),
#   'presion_cabezal_psi': np.float64(1876.0771187988216),
#   'presion_linea_psi': np.float64(794.9922961760024),
#   'temperatura_c': np.float64(80.28593650726957),
#   'choke_percent': np.float64(41.37096635604702),
#   'horas_operativas': np.float64(22.215238091872298)},
#  {'fecha': Timestamp('2022-04-02 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1172.7410684568927),
#   'gas_mscf': np.float64(1401.9377641505434),
#   'agua_bbl': np.float64(249.46187266137426),
#   'presion_cabezal_psi': np.float64(1683.551260646169),
#   'presion_linea_psi': np.float64(789.8163124911517),
#   'temperatura_c': np.float64(79.06105345966738),
#   'choke_percent': np.float64(46.61217673832172),
#   'horas_operativas': np.float64(22.62949190140997)},
#  {'fecha': Timestamp('2022-04-03 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(970.7797321121525),
#   'gas_mscf': np.float64(1113.173562413614),
#   'agua_bbl': np.float64(267.498829103469),
#   'presion_cabezal_psi': np.float64(1759.1366850002973),
#   'presion_linea_psi': np.float64(756.1008706621719),
#   'temperatura_c': np.float64(79.89551198470863),
#   'choke_percent': np.float64(55.97054701523686),
#   'horas_operativas': np.float64(21.59443298082136)},
#  {'fecha': Timestamp('2022-04-04 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1014.231146010644),
#   'gas_mscf': np.float64(1189.3949099454137),
#   'agua_bbl': np.float64(214.51031155632052),
#   'presion_cabezal_psi': np.float64(1836.4052099024552),
#   'presion_linea_psi': np.float64(758.655982298007),
#   'temperatura_c': np.float64(82.15791974913813),
#   'choke_percent': np.float64(45.09417234430159),
#   'horas_operativas': np.float64(23.015618333949604)},
#  {'fecha': Timestamp('2022-04-05 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1005.0241890019051),
#   'gas_mscf': np.float64(1146.1351321728437),
#   'agua_bbl': np.float64(213.10352213557135),
#   'presion_cabezal_psi': np.float64(1684.3655545136364),
#   'presion_linea_psi': np.float64(788.6760554049237),
#   'temperatura_c': np.float64(80.63618625826946),
#   'choke_percent': np.float64(47.67797868845306),
#   'horas_operativas': np.float64(23.902277173786647)},
#  {'fecha': Timestamp('2022-04-06 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(874.9839980417785),
#   'gas_mscf': np.float64(1148.2170542959534),
#   'agua_bbl': np.float64(251.3280258730299),
#   'presion_cabezal_psi': np.float64(1791.537550614596),
#   'presion_linea_psi': np.float64(818.3682753408089),
#   'temperatura_c': np.float64(73.09725243071725),
#   'choke_percent': np.float64(52.31030446625948),
#   'horas_operativas': np.float64(22.09224381985308)},
#  {'fecha': Timestamp('2022-04-07 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1084.6709072878032),
#   'gas_mscf': np.float64(1303.3682663439502),
#   'agua_bbl': np.float64(254.09881728550604),
#   'presion_cabezal_psi': np.float64(1647.3974505081794),
#   'presion_linea_psi': np.float64(845.6792313116624),
#   'temperatura_c': np.float64(86.72952798585018),
#   'choke_percent': np.float64(53.91695254641298),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-04-08 00:00:00'),
#   'pozo': 'POZO-A',
#   'campo': 'CAMPO-A',
#   'petroleo_bbl': np.float64(1078.9958438287165),
#   'gas_mscf': np.float64(1259.8087371948304),
#   'agua_bbl': np.float64(212.29748644601847),
#   'presion_cabezal_psi': np.float64(1720.4632356048785),
#   'presion_linea_psi': np.float64(759.8410524659828),
# ...
#   'agua_bbl': np.float64(209.19033099911314),
#   'presion_cabezal_psi': np.float64(1890.0611267576553),
#   'presion_linea_psi': np.float64(784.4531241824453),
#   'temperatura_c': np.float64(83.14373168705367),
#   'choke_percent': np.float64(53.96355508866832),
#   'horas_operativas': np.float64(21.887672530329418)},
#  {'fecha': Timestamp('2022-08-27 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(660.5371272121214),
#   'gas_mscf': np.float64(954.8846017652037),
#   'agua_bbl': np.float64(252.81833819012064),
#   'presion_cabezal_psi': np.float64(1788.3680847686321),
#   'presion_linea_psi': np.float64(830.4940023595209),
#   'temperatura_c': np.float64(77.19478439151057),
#   'choke_percent': np.float64(42.616713882409734),
#   'horas_operativas': np.float64(21.83224258410008)},
#  {'fecha': Timestamp('2022-08-28 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(913.873135571082),
#   'gas_mscf': np.float64(1340.167895260607),
#   'agua_bbl': np.float64(205.89954906548908),
#   'presion_cabezal_psi': np.float64(1870.9077678741755),
#   'presion_linea_psi': np.float64(798.0036768313319),
#   'temperatura_c': np.float64(77.9489109235509),
#   'choke_percent': np.float64(55.28900503770959),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-08-29 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(933.3914602792004),
#   'gas_mscf': np.float64(1381.6365083988683),
#   'agua_bbl': np.float64(220.77368692720557),
#   'presion_cabezal_psi': np.float64(1655.5210262370315),
#   'presion_linea_psi': np.float64(839.746155693778),
#   'temperatura_c': np.float64(76.10035872370463),
#   'choke_percent': np.float64(47.33928054913449),
#   'horas_operativas': np.float64(21.86436409524217)},
#  {'fecha': Timestamp('2022-08-30 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(816.0718312658664),
#   'gas_mscf': np.float64(1133.996011109546),
#   'agua_bbl': np.float64(189.00263734219055),
#   'presion_cabezal_psi': np.float64(1710.336949118597),
#   'presion_linea_psi': np.float64(867.4567552556715),
#   'temperatura_c': np.float64(81.32849202065943),
#   'choke_percent': np.float64(48.057158897543985),
#   'horas_operativas': np.float64(23.509295323642007)},
#  {'fecha': Timestamp('2022-08-31 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(901.0552933656771),
#   'gas_mscf': np.float64(1365.0216669861386),
#   'agua_bbl': np.float64(206.04195232338293),
#   'presion_cabezal_psi': np.float64(1679.1697465792333),
#   'presion_linea_psi': np.float64(852.908504691205),
#   'temperatura_c': np.float64(81.35283292963558),
#   'choke_percent': np.float64(44.380607974372026),
#   'horas_operativas': np.float64(22.383928784663677)},
#  {'fecha': Timestamp('2022-09-01 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(797.1398245171007),
#   'gas_mscf': np.float64(1184.7959549220457),
#   'agua_bbl': np.float64(246.07017906387577),
#   'presion_cabezal_psi': np.float64(1782.8444590874853),
#   'presion_linea_psi': np.float64(823.5254923689279),
#   'temperatura_c': np.float64(79.08584537541113),
#   'choke_percent': np.float64(51.89023130213942),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-09-02 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(774.7601639541092),
#   'gas_mscf': np.float64(1200.9472492338782),
#   'agua_bbl': np.float64(192.4595983322211),
#   'presion_cabezal_psi': np.float64(1715.3041614820586),
#   'presion_linea_psi': np.float64(800.5931339590392),
#   'temperatura_c': np.float64(80.20882657341028),
#   'choke_percent': np.float64(62.2993599251469),
#   'horas_operativas': np.float64(22.229575200862122)},
#  {'fecha': Timestamp('2022-09-03 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(751.5396757026774),
#   'gas_mscf': np.float64(1083.373144835514),
#   'agua_bbl': np.float64(204.51041040390078),
#   'presion_cabezal_psi': np.float64(1823.9772937034195),
#   'presion_linea_psi': np.float64(750.9605995793221),
#   'temperatura_c': np.float64(76.29951503847727),
#   'choke_percent': np.float64(53.90748619730316),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-09-04 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(753.0740708788068),
#   'gas_mscf': np.float64(1104.846188388213),
#   'agua_bbl': np.float64(241.44588962082167),
#   'presion_cabezal_psi': np.float64(1657.6998288367558),
#   'presion_linea_psi': np.float64(836.9972025689658),
#   'temperatura_c': np.float64(80.04684306665676),
#   'choke_percent': np.float64(45.67857369029732),
#   'horas_operativas': np.float64(23.184858654060363)},
#  {'fecha': Timestamp('2022-09-05 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(634.9035188936869),
#   'gas_mscf': np.float64(892.0942680189656),
#   'agua_bbl': np.float64(227.8810038958923),
#   'presion_cabezal_psi': np.float64(1754.903097332128),
#   'presion_linea_psi': np.float64(883.9873691110764),
#   'temperatura_c': np.float64(75.62309325042624),
#   'choke_percent': np.float64(55.67810292745738),
#   'horas_operativas': np.float64(23.252194854234286)},
#  {'fecha': Timestamp('2022-09-06 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(806.4328067225827),
#   'gas_mscf': np.float64(1169.477587544104),
#   'agua_bbl': np.float64(291.2381607399863),
#   'presion_cabezal_psi': np.float64(1819.0857911012258),
#   'presion_linea_psi': np.float64(817.1053019825209),
#   'temperatura_c': np.float64(77.30109070383796),
#   'choke_percent': np.float64(48.41660227032875),
#   'horas_operativas': np.float64(21.0296914186486)},
#  {'fecha': Timestamp('2022-09-07 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(776.8813055171578),
#   'gas_mscf': np.float64(1118.042678433008),
#   'agua_bbl': np.float64(287.2507318024362),
#   'presion_cabezal_psi': np.float64(1543.6697224959391),
#   'presion_linea_psi': np.float64(895.8629574213062),
#   'temperatura_c': np.float64(75.89496736288586),
#   'choke_percent': np.float64(56.8724249071378),
#   'horas_operativas': np.float64(20.79708664679428)},
#  {'fecha': Timestamp('2022-09-08 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(850.9072035708584),
#   'gas_mscf': np.float64(1316.1997525101453),
#   'agua_bbl': np.float64(219.6713346612393),
#   'presion_cabezal_psi': np.float64(1962.1631307330204),
#   'presion_linea_psi': np.float64(723.7214145969458),
#   'temperatura_c': np.float64(74.96115642522584),
#   'choke_percent': np.float64(54.03338201082181),
#   'horas_operativas': np.float64(22.779434059732687)},
#  {'fecha': Timestamp('2022-09-09 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(788.3680593473556),
#   'gas_mscf': np.float64(1154.6216150709777),
#   'agua_bbl': np.float64(255.26391953499478),
#   'presion_cabezal_psi': np.float64(1721.4848115120124),
#   'presion_linea_psi': np.float64(742.2918307610229),
#   'temperatura_c': np.float64(73.78156884481177),
#   'choke_percent': np.float64(35.28429217264133),
#   'horas_operativas': np.float64(23.246906063416613)},
#  {'fecha': Timestamp('2022-09-10 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(763.4123521633088),
#   'gas_mscf': np.float64(1150.0855556347478),
#   'agua_bbl': np.float64(260.0336306078121),
#   'presion_cabezal_psi': np.float64(1547.0960086323826),
#   'presion_linea_psi': np.float64(842.7600753874132),
#   'temperatura_c': np.float64(79.54627872618049),
#   'choke_percent': np.float64(44.97960183522486),
#   'horas_operativas': np.float64(21.874802172262278)},
#  {'fecha': Timestamp('2022-09-11 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(695.4922264312892),
#   'gas_mscf': np.float64(1028.0078034924616),
#   'agua_bbl': np.float64(226.33068761149255),
#   'presion_cabezal_psi': np.float64(1765.2093898576786),
#   'presion_linea_psi': np.float64(813.2145105076626),
#   'temperatura_c': np.float64(83.74238552518102),
#   'choke_percent': np.float64(54.72192611417695),
#   'horas_operativas': np.float64(21.911306589523658)},
#  {'fecha': Timestamp('2022-09-12 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(784.4969657114792),
#   'gas_mscf': np.float64(1125.9668379267061),
#   'agua_bbl': np.float64(203.84521779061348),
#   'presion_cabezal_psi': np.float64(1752.544346797315),
#   'presion_linea_psi': np.float64(865.6891088285904),
#   'temperatura_c': np.float64(83.02722642817653),
#   'choke_percent': np.float64(50.75828636072509),
#   'horas_operativas': np.float64(23.561472629826135)},
#  {'fecha': Timestamp('2022-09-13 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(847.1622721532015),
#   'gas_mscf': np.float64(1264.0113913029365),
#   'agua_bbl': np.float64(240.89239687535263),
#   'presion_cabezal_psi': np.float64(1740.8105620427507),
#   'presion_linea_psi': np.float64(799.226417963663),
#   'temperatura_c': np.float64(70.87208858023631),
#   'choke_percent': np.float64(44.88122026146075),
#   'horas_operativas': np.float64(23.56285448045713)},
#  {'fecha': Timestamp('2022-09-14 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(667.80034078521),
#   'gas_mscf': np.float64(1025.6646444523587),
#   'agua_bbl': np.float64(236.8448229060369),
#   'presion_cabezal_psi': np.float64(1847.9191112926667),
#   'presion_linea_psi': np.float64(756.6012288735834),
#   'temperatura_c': np.float64(83.58497226714303),
#   'choke_percent': np.float64(46.832052422530936),
#   'horas_operativas': np.float64(22.862258939612072)},
#  {'fecha': Timestamp('2022-09-15 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(784.1158435703143),
#   'gas_mscf': np.float64(1127.8633896537374),
#   'agua_bbl': np.float64(230.23796378314063),
#   'presion_cabezal_psi': np.float64(1823.3444971427054),
#   'presion_linea_psi': np.float64(789.3203378897479),
#   'temperatura_c': np.float64(75.53305404094846),
#   'choke_percent': np.float64(40.4688168995531),
#   'horas_operativas': np.float64(23.780201721186074)},
#  {'fecha': Timestamp('2022-09-16 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(797.3336913383683),
#   'gas_mscf': np.float64(1228.3650486368076),
#   'agua_bbl': np.float64(252.1561141045462),
#   'presion_cabezal_psi': np.float64(1778.1876191023846),
#   'presion_linea_psi': np.float64(723.3658014538133),
#   'temperatura_c': np.float64(80.11325343003551),
#   'choke_percent': np.float64(49.55813356236802),
#   'horas_operativas': np.float64(21.825797704279854)},
#  {'fecha': Timestamp('2022-09-17 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(706.3677120320107),
#   'gas_mscf': np.float64(1025.5627311889082),
#   'agua_bbl': np.float64(222.29607317966446),
#   'presion_cabezal_psi': np.float64(1793.2155633946647),
#   'presion_linea_psi': np.float64(743.5704663451482),
#   'temperatura_c': np.float64(72.56510999069175),
#   'choke_percent': np.float64(61.05344863007882),
#   'horas_operativas': np.float64(22.64406508291303)},
#  {'fecha': Timestamp('2022-09-18 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(718.1272542230175),
#   'gas_mscf': np.float64(1057.8715242916126),
#   'agua_bbl': np.float64(212.23050038036953),
#   'presion_cabezal_psi': np.float64(1737.5641550561913),
#   'presion_linea_psi': np.float64(848.6221998959005),
#   'temperatura_c': np.float64(77.79354497948285),
#   'choke_percent': np.float64(54.02466695366163),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-09-19 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(795.27185133735),
#   'gas_mscf': np.float64(1214.1351019264268),
#   'agua_bbl': np.float64(243.72364380364192),
#   'presion_cabezal_psi': np.float64(1925.3490849240047),
#   'presion_linea_psi': np.float64(843.6393707234805),
#   'temperatura_c': np.float64(78.64058426258744),
#   'choke_percent': np.float64(60.952085005942116),
#   'horas_operativas': np.float64(23.06832212993982)},
#  {'fecha': Timestamp('2022-09-20 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(665.0795219049887),
#   'gas_mscf': np.float64(971.0818365687036),
#   'agua_bbl': np.float64(250.61195709350153),
#   'presion_cabezal_psi': np.float64(1599.6803981642233),
#   'presion_linea_psi': np.float64(818.1502142403039),
#   'temperatura_c': np.float64(69.63813496546526),
#   'choke_percent': np.float64(54.4119854489499),
#   'horas_operativas': np.float64(23.126312514587)},
#  {'fecha': Timestamp('2022-09-21 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(805.3884495741488),
#   'gas_mscf': np.float64(1209.585668734658),
#   'agua_bbl': np.float64(211.51272117482853),
#   'presion_cabezal_psi': np.float64(1761.3651674215898),
#   'presion_linea_psi': np.float64(713.9461239519766),
#   'temperatura_c': np.float64(80.092556175781),
#   'choke_percent': np.float64(55.13739671676346),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-09-22 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(686.4786887767339),
#   'gas_mscf': np.float64(1017.130400013577),
#   'agua_bbl': np.float64(264.09725479815506),
#   'presion_cabezal_psi': np.float64(1753.702463118878),
#   'presion_linea_psi': np.float64(782.0798212243556),
#   'temperatura_c': np.float64(83.77183058930008),
#   'choke_percent': np.float64(59.87039343872512),
#   'horas_operativas': np.float64(21.600657834151228)},
#  {'fecha': Timestamp('2022-09-23 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(871.9005920497377),
#   'gas_mscf': np.float64(1313.0256083427594),
#   'agua_bbl': np.float64(196.59911058735375),
#   'presion_cabezal_psi': np.float64(1828.3280406064594),
#   'presion_linea_psi': np.float64(738.7500055669975),
#   'temperatura_c': np.float64(76.16072750089484),
#   'choke_percent': np.float64(51.88631629671113),
#   'horas_operativas': np.float64(23.79643036664211)},
#  {'fecha': Timestamp('2022-09-24 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(992.4157428714065),
#   'gas_mscf': np.float64(1393.3940500861697),
#   'agua_bbl': np.float64(226.37445682890322),
#   'presion_cabezal_psi': np.float64(1662.41461225751),
#   'presion_linea_psi': np.float64(858.8266626893883),
#   'temperatura_c': np.float64(83.8274984621597),
#   'choke_percent': np.float64(49.0638633924656),
#   'horas_operativas': np.float64(24.0)},
#  {'fecha': Timestamp('2022-09-25 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(687.9433052791776),
#   'gas_mscf': np.float64(958.7276853104432),
#   'agua_bbl': np.float64(234.34323891288514),
#   'presion_cabezal_psi': np.float64(1572.2327397603462),
#   'presion_linea_psi': np.float64(770.81389332187),
#   'temperatura_c': np.float64(76.07176198493572),
#   'choke_percent': np.float64(55.16328758311006),
#   'horas_operativas': np.float64(22.675142073501455)},
#  {'fecha': Timestamp('2022-09-26 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(819.858520904157),
#   'gas_mscf': np.float64(1254.426461598109),
#   'agua_bbl': np.float64(224.85402327788242),
#   'presion_cabezal_psi': np.float64(1762.0823016098193),
#   'presion_linea_psi': np.float64(745.7126144609225),
#   'temperatura_c': np.float64(81.262606721931),
#   'choke_percent': np.float64(57.269201185609425),
#   'horas_operativas': np.float64(23.859630786854847)},
#  {'fecha': Timestamp('2022-09-27 00:00:00'),
#   'pozo': 'POZO-C',
#   'campo': 'CAMPO-C',
#   'petroleo_bbl': np.float64(699.462343332143),
#   'gas_mscf': np.float64(1090.6807712241764),
#   'agua_bbl': np.float64(226.59927278641214),
#   'presion_cabezal_psi': np.float64(1774.3230492218604),
#   'presion_linea_psi': np.float64(801.4898082560712),
#   'temperatura_c': np.float64(65.917173464982),
#   'choke_percent': np.float64(47.60017678643896),
#   'horas_operativas': np.float64(22.017980502789094)},
#  ...]

# %%
# Creamos el DataFrame con todos los datos
df = pd.DataFrame(datos)

# Calculamos campos derivados útiles para el análisis
df['liquido_total'] = df['petroleo_bbl'] + df['agua_bbl']
df['corte_agua'] = df['agua_bbl'] / df['liquido_total']
df['gas_petroleo_ratio'] = df['gas_mscf'] / df['petroleo_bbl']
df['produccion_equivalente'] = df['petroleo_bbl'] + df['gas_mscf'] / 6  # Conversión aproximada

# Mostramos las primeras filas para verificar
print("Vista previa de los datos generados:")
df.head()
# Out:
# Vista previa de los datos generados:
#        fecha    pozo    campo  petroleo_bbl     gas_mscf    agua_bbl  \
# 0 2022-01-01  POZO-A  CAMPO-A   1259.605698  1491.465814  203.916905
# 1 2022-01-02  POZO-A  CAMPO-A   1181.730032  1429.280662  180.654841
# 2 2022-01-03  POZO-A  CAMPO-A   1274.368468  1529.871781  208.609894
# 3 2022-01-04  POZO-A  CAMPO-A   1377.735865  1658.166842  166.615958
# 4 2022-01-05  POZO-A  CAMPO-A   1165.202656  1359.592698  221.473781
#
#    presion_cabezal_psi  presion_linea_psi  temperatura_c  choke_percent  \
# 0          1791.928342         793.077201      82.209703      42.009378
# 1          1807.663519         738.785088      74.599645      52.310863
# 2          1599.779932         789.548837      87.157927      60.121548
# 3          1891.032767         757.473977      79.661918      43.184130
# 4          1833.848848         770.973828      80.300655      50.948531
#
#    horas_operativas  liquido_total  corte_agua  gas_petroleo_ratio  \
# 0         23.534629    1463.522603    0.139333            1.184074
# 1         20.364252    1362.384872    0.132602            1.209482
# 2         23.003376    1482.978362    0.140670            1.200494
# 3         23.327821    1544.351822    0.107887            1.203545
# 4         23.924270    1386.676437    0.159716            1.166829
#
#    produccion_equivalente
# 0             1508.183334
# 1             1419.943476
# 2             1529.347098
# 3             1654.097005
# 4             1391.801439

# %%
df
# Out:
#           fecha    pozo    campo  petroleo_bbl     gas_mscf    agua_bbl  \
# 0    2022-01-01  POZO-A  CAMPO-A   1259.605698  1491.465814  203.916905
# 1    2022-01-02  POZO-A  CAMPO-A   1181.730032  1429.280662  180.654841
# 2    2022-01-03  POZO-A  CAMPO-A   1274.368468  1529.871781  208.609894
# 3    2022-01-04  POZO-A  CAMPO-A   1377.735865  1658.166842  166.615958
# 4    2022-01-05  POZO-A  CAMPO-A   1165.202656  1359.592698  221.473781
# ...         ...     ...      ...           ...          ...         ...
# 1820 2022-12-27  POZO-E  CAMPO-E    440.849855   291.937633  818.083224
# 1821 2022-12-28  POZO-E  CAMPO-E    531.506085   355.327489  819.811081
# 1822 2022-12-29  POZO-E  CAMPO-E    617.516104   394.932310  758.630426
# 1823 2022-12-30  POZO-E  CAMPO-E    475.409235   364.584376  791.915867
# 1824 2022-12-31  POZO-E  CAMPO-E    515.637717   346.543322  693.836803
#
#       presion_cabezal_psi  presion_linea_psi  temperatura_c  choke_percent  \
# 0             1791.928342         793.077201      82.209703      42.009378
# 1             1807.663519         738.785088      74.599645      52.310863
# 2             1599.779932         789.548837      87.157927      60.121548
# 3             1891.032767         757.473977      79.661918      43.184130
# 4             1833.848848         770.973828      80.300655      50.948531
# ...                   ...                ...            ...            ...
# 1820          1642.742741         838.353134      81.196673      43.749872
# 1821          1788.790912         826.899184      83.126305      51.528506
# 1822          1713.151216         835.892311      83.213985      52.757183
# 1823          1730.756765         867.549695      75.258164      53.629106
# 1824          1836.137984         844.181227      80.912354      51.746464
#
#       horas_operativas  liquido_total  corte_agua  gas_petroleo_ratio  \
# 0            23.534629    1463.522603    0.139333            1.184074
# 1            20.364252    1362.384872    0.132602            1.209482
# 2            23.003376    1482.978362    0.140670            1.200494
# 3            23.327821    1544.351822    0.107887            1.203545
# 4            23.924270    1386.676437    0.159716            1.166829
# ...                ...            ...         ...                 ...
# 1820         23.862391    1258.933079    0.649823            0.662216
# 1821         21.382379    1351.317166    0.606676            0.668529
# 1822         23.449713    1376.146530    0.551272            0.639550
# 1823         24.000000    1267.325102    0.624872            0.766885
# 1824         24.000000    1209.474520    0.573668            0.672067
#
#       produccion_equivalente
# 0                1508.183334
# 1                1419.943476
# 2                1529.347098
# 3                1654.097005
# 4                1391.801439
# ...                      ...
# 1820              489.506127
# 1821              590.727333
# 1822              683.338156
# 1823              536.173298
# 1824              573.394937
#
# [1825 rows x 15 columns]

# %%
df.shape
# Out:
# (1825, 15)

# %%
df.columns
# Out:
# Index(['fecha', 'pozo', 'campo', 'petroleo_bbl', 'gas_mscf', 'agua_bbl',
#        'presion_cabezal_psi', 'presion_linea_psi', 'temperatura_c',
#        'choke_percent', 'horas_operativas', 'liquido_total', 'corte_agua',
#        'gas_petroleo_ratio', 'produccion_equivalente'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fecha                   1825 non-null   datetime64[ns]
#  1   pozo                    1825 non-null   object
#  2   campo                   1825 non-null   object
#  3   petroleo_bbl            1825 non-null   float64
#  4   gas_mscf                1825 non-null   float64
#  5   agua_bbl                1825 non-null   float64
#  6   presion_cabezal_psi     1825 non-null   float64
#  7   presion_linea_psi       1825 non-null   float64
#  8   temperatura_c           1825 non-null   float64
#  9   choke_percent           1825 non-null   float64
#  10  horas_operativas        1825 non-null   float64
#  11  liquido_total           1825 non-null   float64
#  12  corte_agua              1825 non-null   float64
#  13  gas_petroleo_ratio      1825 non-null   float64
#  14  produccion_equivalente  1825 non-null   float64
# dtypes: datetime64[ns](1), float64(12), object(2)
# memory usage: 214.0+ KB

# %%
df.describe() # Como metodo .describe() y no como atributo .describe
# Out:
#                                fecha  petroleo_bbl     gas_mscf     agua_bbl  \
# count                           1825   1825.000000  1825.000000  1825.000000
# mean   2022-07-02 00:00:00.000000256    881.963064   973.320973   324.572474
# min              2022-01-01 00:00:00    163.006778    85.524819    77.391472
# 25%              2022-04-02 00:00:00    650.718321   522.405512   209.447511
# 50%              2022-07-02 00:00:00    842.387910  1114.371215   256.637242
# 75%              2022-10-01 00:00:00   1138.152105  1365.085252   309.894627
# max              2022-12-31 00:00:00   2037.002906  2485.873766   986.139004
# std                              NaN    327.456762   473.391522   216.901299
#
#        presion_cabezal_psi  presion_linea_psi  temperatura_c  choke_percent  \
# count          1825.000000        1825.000000    1825.000000    1825.000000
# mean           1764.023397         800.388854      80.046137      49.975162
# min            1433.975106         615.581735      62.508454      30.816722
# 25%            1692.015523         766.948906      76.299515      46.676495
# 50%            1764.749148         800.734705      79.957900      49.793537
# 75%            1835.512145         834.716319      83.764559      53.411694
# max            2075.065444         971.445524      97.980409      66.886915
# std             104.288919          49.695904       5.447616       5.042566
#
#        horas_operativas  liquido_total   corte_agua  gas_petroleo_ratio  \
# count       1825.000000    1825.000000  1825.000000         1825.000000
# mean          22.921134    1206.535537     0.280329            1.059526
# min           19.670496     426.918789     0.053414            0.451341
# 25%           22.355660    1049.784154     0.159975            0.777208
# 50%           23.003376    1188.151367     0.230937            1.097622
# 75%           23.644311    1350.210139     0.307943            1.226407
# max           24.000000    2277.988269     0.797238            1.755897
# std            0.860390     229.074862     0.184610            0.289902
#
#        produccion_equivalente
# count             1825.000000
# mean              1044.183226
# min                185.919978
# 25%                746.326372
# 50%               1010.776832
# 75%               1358.205588
# max               2451.315200
# std                400.842917

# %% [markdown]
# ## 2. Estadísticas Descriptivas para Datos de Producción
#
# Las estadísticas descriptivas son fundamentales para entender nuestros datos:
# - Medidas de tendencia central (media, mediana)
# - Medidas de dispersión (desviación estándar, rango)
# - Percentiles y distribuciones
# - Correlaciones entre variables
#
# Estas métricas nos dan una primera visión sobre el comportamiento de los pozos.

# %%
# Estadísticas descriptivas generales
print("Estadísticas descriptivas de todo el dataset:")
descripcion = df.describe().T
descripcion['cv'] = descripcion['std'] / descripcion['mean']  # Coeficiente de variación
descripcion
# Out:
# Estadísticas descriptivas de todo el dataset:
#                          count                           mean  \
# fecha                     1825  2022-07-02 00:00:00.000000256
# petroleo_bbl            1825.0                     881.963064
# gas_mscf                1825.0                     973.320973
# agua_bbl                1825.0                     324.572474
# presion_cabezal_psi     1825.0                    1764.023397
# presion_linea_psi       1825.0                     800.388854
# temperatura_c           1825.0                      80.046137
# choke_percent           1825.0                      49.975162
# horas_operativas        1825.0                      22.921134
# liquido_total           1825.0                    1206.535537
# corte_agua              1825.0                       0.280329
# gas_petroleo_ratio      1825.0                       1.059526
# produccion_equivalente  1825.0                    1044.183226
#
#                                         min                  25%  \
# fecha                   2022-01-01 00:00:00  2022-04-02 00:00:00
# petroleo_bbl                     163.006778           650.718321
# gas_mscf                          85.524819           522.405512
# agua_bbl                          77.391472           209.447511
# presion_cabezal_psi             1433.975106          1692.015523
# presion_linea_psi                615.581735           766.948906
# temperatura_c                     62.508454            76.299515
# choke_percent                     30.816722            46.676495
# horas_operativas                  19.670496             22.35566
# liquido_total                    426.918789          1049.784154
# corte_agua                         0.053414             0.159975
# gas_petroleo_ratio                 0.451341             0.777208
# produccion_equivalente           185.919978           746.326372
#
#                                         50%                  75%  \
# fecha                   2022-07-02 00:00:00  2022-10-01 00:00:00
# petroleo_bbl                      842.38791          1138.152105
# gas_mscf                        1114.371215          1365.085252
# agua_bbl                         256.637242           309.894627
# presion_cabezal_psi             1764.749148          1835.512145
# presion_linea_psi                800.734705           834.716319
# temperatura_c                       79.9579            83.764559
# choke_percent                     49.793537            53.411694
# horas_operativas                  23.003376            23.644311
# liquido_total                   1188.151367          1350.210139
# corte_agua                         0.230937             0.307943
# gas_petroleo_ratio                 1.097622             1.226407
# produccion_equivalente          1010.776832          1358.205588
#
#                                         max         std        cv
# fecha                   2022-12-31 00:00:00         NaN       NaN
# petroleo_bbl                    2037.002906  327.456762  0.371282
# gas_mscf                        2485.873766  473.391522  0.486367
# agua_bbl                         986.139004  216.901299  0.668268
# presion_cabezal_psi             2075.065444  104.288919   0.05912
# presion_linea_psi                971.445524   49.695904   0.06209
# temperatura_c                     97.980409    5.447616  0.068056
# choke_percent                     66.886915    5.042566  0.100901
# horas_operativas                       24.0     0.86039  0.037537
# liquido_total                   2277.988269  229.074862  0.189862
# corte_agua                         0.797238     0.18461  0.658548
# gas_petroleo_ratio                 1.755897    0.289902  0.273614
# produccion_equivalente            2451.3152  400.842917  0.383882

# %%
# Analizamos por pozo
print("\nPetróleo promedio por pozo (bbl/día):")
df.groupby('pozo')['petroleo_bbl'].mean().sort_values(ascending=False)
# Out:
# Petróleo promedio por pozo (bbl/día):
# pozo
# POZO-D    1265.003922
# POZO-A    1151.168944
# POZO-C     785.860574
# POZO-B     735.624290
# POZO-E     472.157589
# Name: petroleo_bbl, dtype: float64

# %%
df.groupby('pozo')["gas_mscf"].max()
# Out:
# pozo
# POZO-A    2485.873766
# POZO-B     767.342881
# POZO-C    1783.229465
# POZO-D    1931.954982
# POZO-E     543.190559
# Name: gas_mscf, dtype: float64

# %%
df.groupby('pozo')["gas_mscf"].min()
# Out:
# pozo
# POZO-A    790.552426
# POZO-B    379.519199
# POZO-C    273.765450
# POZO-D    878.963623
# POZO-E     85.524819
# Name: gas_mscf, dtype: float64

# %%
print("\nProducción total acumulada por pozo:")
produccion_acumulada = df.groupby('pozo').agg({
    'petroleo_bbl': 'sum',
    'gas_mscf': 'sum',
    'agua_bbl': 'sum'
})
produccion_acumulada
# Out:
# Producción total acumulada por pozo:
#          petroleo_bbl       gas_mscf       agua_bbl
# pozo
# POZO-A  420176.664551  503518.239777   90896.719232
# POZO-B  268502.865811  215141.969225  103307.740282
# POZO-C  286839.109376  429721.050000   88256.341746
# POZO-D  461726.431372  506954.576436   41599.623478
# POZO-E  172337.519940  120974.939579  268284.339952

# %%
df.groupby('pozo')['petroleo_bbl'].sum()
# Out:
# pozo
# POZO-A    420176.664551
# POZO-B    268502.865811
# POZO-C    286839.109376
# POZO-D    461726.431372
# POZO-E    172337.519940
# Name: petroleo_bbl, dtype: float64

# %%
# Análisis de tendencia mensual (promediando por mes) 
df['mes'] = df['fecha'].dt.strftime('%Y-%m')
tendencia_mensual = df.groupby(['pozo', 'mes']).agg({
    'petroleo_bbl': 'mean',
    'gas_mscf': 'mean',
    'agua_bbl': 'mean'
}).reset_index()

print("\nTendencia mensual de producción (primeros 5 meses):")
tendencia_mensual.head()
#tendencia_mensual.head(10)
#tendencia_mensual.tail(10)
#tendencia_mensual.sample(10)
# Out:
# Tendencia mensual de producción (primeros 5 meses):
#      pozo      mes  petroleo_bbl     gas_mscf    agua_bbl
# 0  POZO-A  2022-01   1150.984739  1388.641354  200.957454
# 1  POZO-A  2022-02   1110.436984  1340.714837  216.588936
# 2  POZO-A  2022-03   1087.298649  1294.469148  217.744792
# 3  POZO-A  2022-04   1034.375820  1238.373886  227.160290
# 4  POZO-A  2022-05    983.427964  1174.562323  236.462608

# %%
tendencia_mensual.loc[tendencia_mensual.mes=="2022-01"]
# Out:
#       pozo      mes  petroleo_bbl     gas_mscf    agua_bbl
# 0   POZO-A  2022-01   1150.984739  1388.641354  200.957454
# 12  POZO-B  2022-01    793.069032   637.190250  302.512430
# 24  POZO-C  2022-01    892.475988  1335.250230  247.635800
# 36  POZO-D  2022-01   1482.566700  1636.241136  103.724734
# 48  POZO-E  2022-01    521.382148   368.024434  699.643841

# %%
tendencia_mensual.loc[(tendencia_mensual.agua_bbl < 300) & (tendencia_mensual.agua_bbl > 200)]
# Out:
#       pozo      mes  petroleo_bbl     gas_mscf    agua_bbl
# 0   POZO-A  2022-01   1150.984739  1388.641354  200.957454
# 1   POZO-A  2022-02   1110.436984  1340.714837  216.588936
# 2   POZO-A  2022-03   1087.298649  1294.469148  217.744792
# 3   POZO-A  2022-04   1034.375820  1238.373886  227.160290
# 4   POZO-A  2022-05    983.427964  1174.562323  236.462608
# 5   POZO-A  2022-06   1003.718611  1186.216679  249.609464
# 6   POZO-A  2022-07   1385.987014  1662.482479  248.544837
# 7   POZO-A  2022-08   1306.315079  1574.526718  261.653419
# 8   POZO-A  2022-09   1239.043491  1495.339307  263.117779
# 9   POZO-A  2022-10   1214.680233  1449.152137  281.479522
# 10  POZO-A  2022-11   1194.568759  1434.179065  286.600998
# 11  POZO-A  2022-12   1094.958857  1306.325721  296.304888
# 14  POZO-B  2022-03    771.936233   612.290547  289.142679
# 15  POZO-B  2022-04    735.971925   595.199248  289.454171
# 16  POZO-B  2022-05    745.288077   602.750213  276.052952
# 17  POZO-B  2022-06    755.765848   601.886048  277.302556
# 18  POZO-B  2022-07    730.795074   579.580266  278.173592
# 19  POZO-B  2022-08    700.653588   557.729646  276.348839
# 20  POZO-B  2022-09    708.450476   573.167419  281.686251
# 21  POZO-B  2022-10    709.000983   567.453970  278.258216
# 22  POZO-B  2022-11    700.011157   565.407934  282.873171
# 23  POZO-B  2022-12    692.794624   549.748652  258.557061
# 24  POZO-C  2022-01    892.475988  1335.250230  247.635800
# 25  POZO-C  2022-02    752.178991  1129.846921  246.809831
# 26  POZO-C  2022-03    887.604417  1335.935959  246.710293
# 27  POZO-C  2022-04    880.079658  1322.756724  240.104993
# 28  POZO-C  2022-05    821.708137  1230.988301  249.270832
# 29  POZO-C  2022-06    835.795611  1257.170111  239.258710
# 30  POZO-C  2022-07    702.069412  1048.328324  245.318794
# 31  POZO-C  2022-08    829.827987  1229.470126  237.244276
# 32  POZO-C  2022-09    768.277956  1137.830990  237.929468
# 33  POZO-C  2022-10    613.861031   928.630636  240.505080
# 34  POZO-C  2022-11    722.759842  1086.057402  235.802645
# 35  POZO-C  2022-12    722.475789  1084.005436  235.017892

# %%
# Análisis de correlación entre variables
print("\nMatriz de correlación entre variables principales:")
columnas_correlacion = ['petroleo_bbl', 'gas_mscf', 'agua_bbl', 
                        'presion_cabezal_psi', 'presion_linea_psi', 
                        'temperatura_c', 'choke_percent', 'horas_operativas']
matriz_correlacion = df[columnas_correlacion].corr()
matriz_correlacion

# Valores cercanos a 0 no hay correlacion
# Valores cercanos a 1 hay correlacion directa
# Valores negativos cercanos a 1 avisa que hay correlacion inversa
# Correlacion usa el metodo de Pearson
# Out:
# Matriz de correlación entre variables principales:
#                      petroleo_bbl  gas_mscf  agua_bbl  presion_cabezal_psi  \
# petroleo_bbl             1.000000  0.913887 -0.716633             0.040607
# gas_mscf                 0.913887  1.000000 -0.743470             0.045634
# agua_bbl                -0.716633 -0.743470  1.000000            -0.006171
# presion_cabezal_psi      0.040607  0.045634 -0.006171             1.000000
# presion_linea_psi       -0.012117 -0.015975  0.017587             0.005337
# temperatura_c           -0.020393 -0.012329  0.019204             0.071490
# choke_percent           -0.008711 -0.002308  0.006912             0.054524
# horas_operativas         0.008906  0.020356 -0.011445            -0.013898
#
#                      presion_linea_psi  temperatura_c  choke_percent  \
# petroleo_bbl                 -0.012117      -0.020393      -0.008711
# gas_mscf                     -0.015975      -0.012329      -0.002308
# agua_bbl                      0.017587       0.019204       0.006912
# presion_cabezal_psi           0.005337       0.071490       0.054524
# presion_linea_psi             1.000000       0.019428      -0.013194
# temperatura_c                 0.019428       1.000000       0.019769
# choke_percent                -0.013194       0.019769       1.000000
# horas_operativas             -0.046849       0.001617      -0.051943
#
#                      horas_operativas
# petroleo_bbl                 0.008906
# gas_mscf                     0.020356
# agua_bbl                    -0.011445
# presion_cabezal_psi         -0.013898
# presion_linea_psi           -0.046849
# temperatura_c                0.001617
# choke_percent               -0.051943
# horas_operativas             1.000000

# %% [markdown]
# ## 3. Visualización de Series Temporales de Producción
#
# Las series temporales son fundamentales en datos de producción petrolera.
# Visualizarlas adecuadamente nos permite:
# - Identificar tendencias de declive natural
# - Detectar eventos operativos (cierres, intervenciones)
# - Analizar patrones estacionales o cíclicos
# - Comparar rendimiento entre pozos

# %%
# Gráfico de series temporales de producción de petróleo por pozo
plt.figure(figsize=(12, 6))
for pozo in pozos:
    datos_pozo = df[df['pozo'] == pozo]
    plt.plot(datos_pozo['fecha'], datos_pozo['petroleo_bbl'], label=pozo)

plt.title('Producción de Petróleo por Pozo (bbl/día)', fontsize=14)
plt.xlabel('Fecha', fontsize=12)
plt.ylabel('Producción (bbl/día)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Gráfico de producción acumulada
plt.figure(figsize=(12, 6))
for pozo in pozos:
    datos_pozo = df[df['pozo'] == pozo]
    plt.plot(datos_pozo['fecha'], datos_pozo['petroleo_bbl'].cumsum(), label=pozo)

plt.title('Producción Acumulada de Petróleo por Pozo', fontsize=14)
plt.xlabel('Fecha', fontsize=12)
plt.ylabel('Producción Acumulada (bbl)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Visualización de múltiples parámetros para un solo pozo
pozo_analisis = 'POZO-A'
datos_pozo = df[df['pozo'] == pozo_analisis]

# Creamos una figura con subplots
fig, axes = plt.subplots(3, 1, figsize=(12, 12), sharex=True)

# Producción (petróleo, gas, agua)
axes[0].plot(datos_pozo['fecha'], datos_pozo['petroleo_bbl'], 'g-', label='Petróleo (bbl)')
axes[0].plot(datos_pozo['fecha'], datos_pozo['agua_bbl'], 'b-', label='Agua (bbl)')
axes[0].set_ylabel('Producción (bbl/día)')
axes[0].set_title(f'Análisis de Producción - {pozo_analisis}')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Línea secundaria para el gas (escala diferente)
ax_gas = axes[0].twinx()
ax_gas.plot(datos_pozo['fecha'], datos_pozo['gas_mscf'], 'r-', label='Gas (mscf)')
ax_gas.set_ylabel('Gas (mscf/día)')
ax_gas.legend(loc='upper right')

# Presiones
axes[1].plot(datos_pozo['fecha'], datos_pozo['presion_cabezal_psi'], 'r-', label='P. Cabezal')
axes[1].plot(datos_pozo['fecha'], datos_pozo['presion_linea_psi'], 'b-', label='P. Línea')
axes[1].set_ylabel('Presión (psi)')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

# Parámetros operativos
axes[2].plot(datos_pozo['fecha'], datos_pozo['choke_percent'], 'g-', label='Choke (%)')
axes[2].set_ylabel('Choke (%)')
axes[2].set_xlabel('Fecha')
axes[2].legend(loc='upper left')
axes[2].grid(True, alpha=0.3)

# Línea secundaria para horas operativas
ax_horas = axes[2].twinx()
ax_horas.plot(datos_pozo['fecha'], datos_pozo['horas_operativas'], 'k-', alpha=0.5, label='Hrs. Op.')
ax_horas.set_ylabel('Horas Operativas')
ax_horas.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Análisis de Relaciones entre Variables
#
# Entender cómo se relacionan las variables nos permite:
# - Identificar factores que afectan la producción
# - Optimizar parámetros operativos
# - Predecir comportamientos futuros
# - Detectar anomalías o comportamientos no esperados

# %%
# Gráfico de dispersión: Relación entre presión de cabezal y producción
plt.figure(figsize=(10, 6))
for pozo in pozos:
    datos_pozo = df[df['pozo'] == pozo]
    plt.scatter(datos_pozo['presion_cabezal_psi'], datos_pozo['petroleo_bbl'], 
               alpha=0.6, label=pozo)

plt.title('Relación entre Presión de Cabezal y Producción de Petróleo', fontsize=14)
plt.xlabel('Presión de Cabezal (psi)', fontsize=12)
plt.ylabel('Producción de Petróleo (bbl/día)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Mapa de calor de correlaciones
plt.figure(figsize=(12, 10))
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Mapa de Calor: Correlaciones entre Variables Operativas', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Pairplot para analizar múltiples relaciones entre variables
variables_clave = ['petroleo_bbl', 'gas_mscf', 'agua_bbl', 
                  'presion_cabezal_psi', 'choke_percent']
sns.pairplot(df.sample(1000), vars=variables_clave, hue='pozo', height=2.5)
plt.suptitle('Relaciones entre Variables Clave por Pozo', y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# ## 5. Detección de Outliers y Eventos Anómalos
#
# Los outliers pueden representar:
# - Errores de medición o registro
# - Eventos operativos reales (cierres, pruebas)
# - Comportamientos anómalos que requieren atención
#
# Identificarlos es crucial para análisis correctos y toma de decisiones.

# %%
# Gráfico de boxplot para identificar outliers por pozo
plt.figure(figsize=(12, 6))
sns.boxplot(x='pozo', y='petroleo_bbl', data=df)
plt.title('Distribución y Outliers de Producción de Petróleo por Pozo', fontsize=14)
plt.xlabel('Pozo', fontsize=12)
plt.ylabel('Producción de Petróleo (bbl/día)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Método estadístico para detectar outliers (Z-score)
def detectar_outliers_zscore(df, columna, umbral=3):
    """Detecta outliers usando Z-score"""
    z_scores = abs((df[columna] - df[columna].mean()) / df[columna].std())
    return df[z_scores > umbral]

# %%
# Detectamos outliers por pozo usando Z-score
for pozo in pozos:
    datos_pozo = df[df['pozo'] == pozo]
    outliers = detectar_outliers_zscore(datos_pozo, 'petroleo_bbl', umbral=2.5)
    
    if not outliers.empty:
        print(f"\nOutliers detectados en {pozo} (producción de petróleo):")
        print(outliers[['fecha', 'petroleo_bbl', 'gas_mscf', 'agua_bbl']].head())
# Out:
# Outliers detectados en POZO-A (producción de petróleo):
#          fecha  petroleo_bbl     gas_mscf    agua_bbl
# 209 2022-07-29   2037.002906  2485.873766  240.985364
# 220 2022-08-09   1739.625158  2099.961218  250.543701
# 234 2022-08-23   1683.227158  2038.737614  257.576263
# 252 2022-09-10   1647.032308  2012.727100  245.269915
# 262 2022-09-20    664.034810   790.552426  262.621727
#
# Outliers detectados en POZO-B (producción de petróleo):
#          fecha  petroleo_bbl    gas_mscf    agua_bbl
# 434 2022-03-11    968.729647  757.169375  290.893762
# 597 2022-08-21    488.926257  403.872824  225.253485
# 727 2022-12-29    508.718248  413.356792  240.684121
#
# Outliers detectados en POZO-C (producción de petróleo):
#          fecha  petroleo_bbl    gas_mscf    agua_bbl
# 780 2022-02-20    267.496996  347.437107  257.384393
# 781 2022-02-21    294.162695  401.106486  247.235600
# 782 2022-02-22    233.681713  337.268478  231.816435
# 783 2022-02-23    230.011751  401.674099  196.907037
# 784 2022-02-24    285.977007  459.895109  257.448373
#
# Outliers detectados en POZO-D (producción de petróleo):
#           fecha  petroleo_bbl     gas_mscf    agua_bbl
# 1104 2022-01-10   1722.143602  1882.773037  113.876055
# 1345 2022-09-08    796.754343   949.738059  105.082986
# 1453 2022-12-25    728.410181   878.963623  122.955594
#
# Outliers detectados en POZO-E (producción de petróleo):
#           fecha  petroleo_bbl    gas_mscf    agua_bbl
# 1509 2022-02-19    737.554593  543.190559  861.910233
# 1525 2022-03-07    187.307111  121.991611  683.597299
# 1729 2022-09-27    207.390439  181.706249  761.864006
# 1731 2022-09-29    163.006778  137.479201  640.923858
# 1747 2022-10-15    189.490283   85.524819  717.806519

# %%
# Visualización de outliers en la serie temporal
plt.figure(figsize=(12, 6))
for pozo in pozos:
    datos_pozo = df[df['pozo'] == pozo]
    
    # Graficamos la serie normal
    plt.plot(datos_pozo['fecha'], datos_pozo['petroleo_bbl'], alpha=0.7, label=pozo)
    
    # Identificamos outliers
    outliers = detectar_outliers_zscore(datos_pozo, 'petroleo_bbl', umbral=2.5)
    
    # Marcamos los outliers
    if not outliers.empty:
        plt.scatter(outliers['fecha'], outliers['petroleo_bbl'], 
                   color='red', marker='o', s=50, label=f'{pozo} - Outliers')

plt.title('Producción de Petróleo con Outliers Identificados', fontsize=14)
plt.xlabel('Fecha', fontsize=12)
plt.ylabel('Producción (bbl/día)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Visualizaciones Avanzadas con Plotly (Interactivas)
#
# Las visualizaciones interactivas proporcionan:
# - Exploración más profunda de los datos
# - Comunicación efectiva con stakeholders
# - Capacidad para "contar historias" con los datos
# - Análisis drill-down para identificar causas raíz

# %%
# Gráfico interactivo de producción por pozo
fig = px.line(df, x='fecha', y='petroleo_bbl', color='pozo',
             title='Producción de Petróleo por Pozo (Interactivo)',
             labels={'petroleo_bbl': 'Producción (bbl/día)',
                    'fecha': 'Fecha'})
fig.update_layout(xaxis_title='Fecha',
                 yaxis_title='Producción (bbl/día)',
                 legend_title='Pozo',
                 hovermode='closest')
fig.show()

# %%
# Dashboard interactivo con múltiples indicadores
fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=('Producción de Petróleo', 'Corte de Agua', 
                   'Relación Gas-Petróleo', 'Producción Acumulada'),
    specs=[[{"type": "scatter"}, {"type": "scatter"}],
           [{"type": "scatter"}, {"type": "bar"}]]
)

# 1. Producción de petróleo
for pozo in pozos:
    datos_pozo = df[df['pozo'] == pozo]
    fig.add_trace(
        go.Scatter(x=datos_pozo['fecha'], y=datos_pozo['petroleo_bbl'],
                  name=pozo, mode='lines'),
        row=1, col=1
    )

# 2. Corte de agua
for pozo in pozos:
    datos_pozo = df[df['pozo'] == pozo]
    fig.add_trace(
        go.Scatter(x=datos_pozo['fecha'], y=datos_pozo['corte_agua'],
                  name=pozo, mode='lines', visible='legendonly'),
        row=1, col=2
    )

# 3. Relación gas-petróleo
for pozo in pozos:
    datos_pozo = df[df['pozo'] == pozo]
    fig.add_trace(
        go.Scatter(x=datos_pozo['fecha'], y=datos_pozo['gas_petroleo_ratio'],
                  name=pozo, mode='lines', visible='legendonly'),
        row=2, col=1
    )

# 4. Producción acumulada
fig.add_trace(
    go.Bar(x=produccion_acumulada.index, y=produccion_acumulada['petroleo_bbl'],
          name='Petróleo Acumulado'),
    row=2, col=2
)

# Actualizar layout
fig.update_layout(height=800, width=1000, title_text="Dashboard de Producción Petrolera",
                 legend_title='Pozo')
fig.show()

# %% [markdown]
# ## 7. Ejercicios Prácticos para el Estudiante
#
# Ahora es tu turno de aplicar lo aprendido con estos ejercicios prácticos.
# Intenta resolverlos usando las técnicas y herramientas que hemos visto.

# %%
# EJERCICIO 1: Identificar el pozo con mayor variabilidad en producción
# PISTA: Usa el coeficiente de variación (CV = desviación estándar / media)

# Tu código aquí

# %%
# EJERCICIO 2: Crea un gráfico que muestre la evolución del corte de agua para cada pozo
# PISTA: Usa plt.figure() y un bucle para graficar cada pozo con diferente color

# Tu código aquí

# %%
# EJERCICIO 3: Encuentra qué parámetro operativo tiene mayor correlación con la producción de petróleo
# PISTA: Usa la matriz de correlación que ya calculamos

# Tu código aquí

# %% [markdown]
# ## 8. Conclusiones y Mejores Prácticas
#
# Resumen de lo aprendido:
#
# 1. El análisis exploratorio de datos (EDA) es fundamental para entender el comportamiento
#    de los pozos y detectar oportunidades de optimización.
#
# 2. Las visualizaciones efectivas transforman datos complejos en insights accionables,
#    facilitando la comunicación con stakeholders.
#
# 3. Las técnicas estadísticas nos ayudan a cuantificar patrones, tendencias y relaciones
#    entre variables operativas.
#
# 4. La detección de outliers y eventos anómalos permite identificar problemas operativos
#    o errores en los datos.
#
# 5. Las herramientas interactivas como Plotly permiten análisis más profundos y
#    comunicación efectiva de resultados.
#
# Mejores prácticas:
#
# - Siempre comienza con estadísticas descriptivas básicas
# - Combina diferentes tipos de visualizaciones
# - Considera el contexto operativo al interpretar los datos
# - Documenta todos tus hallazgos con visualizaciones claras
# - Utiliza herramientas interactivas para presentaciones a stakeholders

# %%
print("¡Laboratorio completado con éxito!")
